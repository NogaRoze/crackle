# %% [markdown]
# # Introduction

# %% [markdown]
# This notebook demonstrates how to train custom openWakeWord models using pre-defined datasets and an automated process for dataset generation and training. While not guaranteed to always produce the best performing model, the methods shown in this notebook often produce baseline models with releatively strong performance.
#
# Manual data preparation and model training (e.g., see the [training models](training_models.ipynb) notebook) remains an option for when full control over the model development process is needed.
#
# At a high level, the automatic training process takes advantages of several techniques to try and produce a good model, including:
#
# - Early-stopping and checkpoint averaging (similar to [stochastic weight averaging](https://arxiv.org/abs/1803.05407)) to search for the best models found during training, according to the validation data
# - Variable learning rates with cosine decay and multiple cycles
# - Adaptive batch construction to focus on only high-loss examples when the model begins to converge, combined with gradient accumulation to ensure that batch sizes are still large enough for stable training
# - Cycical weight schedules for negative examples to help the model reduce false-positive rates
#
# See the contents of the `train.py` file for more details.

# %% [markdown]
# # Environment Setup

# %% [markdown]
# To begin, we'll need to install the requirements for training custom models. In particular, a relatively recent version of Pytorch and custom fork of the [piper-sample-generator](https://github.com/dscripka/piper-sample-generator) library for generating synthetic examples for the custom model.
#
# **Important Note!** Currently, automated model training is only supported on linux systems due to the requirements of the text to speech library used for synthetic sample generation (Piper). It may be possible to use Piper on Windows/Mac systems, but that has not (yet) been tested.

# %%
## Environment setup

# install piper-sample-generator (currently only supports linux systems)
# !git clone https://github.com/rhasspy/piper-sample-generator
# !wget -O piper-sample-generator/models/en_US-libritts_r-medium.pt 'https://github.com/rhasspy/piper-sample-generator/releases/download/v2.0.0/en_US-libritts_r-medium.pt'
# !pip install piper-phonemize-cross
# !pip install webrtcvad

# install openwakeword (full installation to support training)
# !git clone https://github.com/dscripka/openwakeword
# !pip install -e ./openwakeword
# !cd openwakeword

# install other dependencies
# !pip install mutagen==1.47.0
# !pip install torchinfo==1.8.0
# !pip install torchmetrics==1.2.0
# !pip install speechbrain==0.5.14
# !pip install audiomentations==0.33.0
# !pip install torch-audiomentations==0.11.0
# !pip install acoustics==0.2.6
# !pip install tensorflow-cpu==2.8.1
# !pip install tensorflow_probability==0.16.0
# !pip install onnx_tf==1.10.0
# !pip install pronouncing==0.2.0
# !pip install datasets
# !pip install deep-phonemizer==0.0.19

# Download required models (workaround for Colab)
import os  
os.makedirs("./openwakeword/openwakeword/resources/models", exist_ok=True)
# !wget https://github.com/dscripka/openWakeWord/releases/download/v0.5.1/embedding_model.onnx -O ./openwakeword/openwakeword/resources/models/embedding_model.onnx
# !wget https://github.com/dscripka/openWakeWord/releases/download/v0.5.1/embedding_model.tflite -O ./openwakeword/openwakeword/resources/models/embedding_model.tflite
# !wget https://github.com/dscripka/openWakeWord/releases/download/v0.5.1/melspectrogram.onnx -O ./openwakeword/openwakeword/resources/models/melspectrogram.onnx
# !wget https://github.com/dscripka/openWakeWord/releases/download/v0.5.1/melspectrogram.tflite -O ./openwakeword/openwakeword/resources/models/melspectrogram.tflite
# Out:
# fatal: destination path 'piper-sample-generator' already exists and is not an empty directory.
# --2025-10-23 19:52:57--  https://github.com/rhasspy/piper-sample-generator/releases/download/v2.0.0/en_US-libritts_r-medium.pt
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/642029941/73f4af3c-7cf8-4547-a7b9-3bd29e7f3c33?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-10-24T01%3A27%3A39Z&rscd=attachment%3B+filename%3Den_US-libritts_r-medium.pt&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-10-24T00%3A27%3A06Z&ske=2025-10-24T01%3A27%3A39Z&sks=b&skv=2018-11-09&sig=%2Fg7zqtzMdDM%2Fomvcb0huTWa%2FzQbCN6pc9TZpB1LPNvE%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2MTI3MDc3NywibmJmIjoxNzYxMjY3MTc3LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.V1jnyAl-AJCo1TM-vLeemRirpjztqdKqYY4U7VLjbHs&response-content-disposition=attachment%3B%20filename%3Den_US-libritts_r-medium.pt&response-content-type=application%2Foctet-stream [following]
# --2025-10-23 19:52:57--  https://release-assets.githubusercontent.com/github-production-release-asset/642029941/73f4af3c-7cf8-4547-a7b9-3bd29e7f3c33?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-10-24T01%3A27%3A39Z&rscd=attachment%3B+filename%3Den_US-libritts_r-medium.pt&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-10-24T00%3A27%3A06Z&ske=2025-10-24T01%3A27%3A39Z&sks=b&skv=2018-11-09&sig=%2Fg7zqtzMdDM%2Fomvcb0huTWa%2FzQbCN6pc9TZpB1LPNvE%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2MTI3MDc3NywibmJmIjoxNzYxMjY3MTc3LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.V1jnyAl-AJCo1TM-vLeemRirpjztqdKqYY4U7VLjbHs&response-content-disposition=attachment%3B%20filename%3Den_US-libritts_r-medium.pt&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 204089915 (195M) [application/octet-stream]
# Saving to: ‘piper-sample-generator/models/en_US-libritts_r-medium.pt’
#
# piper-sample-genera 100%[===================>] 194.63M  38.2MB/s    in 5.1s
#
# 2025-10-23 19:53:02 (38.1 MB/s) - ‘piper-sample-generator/models/en_US-libritts_r-medium.pt’ saved [204089915/204089915]
#
# Requirement already satisfied: piper-phonemize-cross in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (1.2.1)
# Requirement already satisfied: webrtcvad in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (2.0.10)
# fatal: destination path 'openwakeword' already exists and is not an empty directory.
# Obtaining file:///Users/nogarosenberg/crackle_ws/crackle/crackle_planning/crackle_planning/openWakeWord/notebooks/openwakeword
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: onnxruntime<2,>=1.10.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from openwakeword==0.6.0) (1.23.2)
# Requirement already satisfied: tqdm<5.0,>=4.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from openwakeword==0.6.0) (4.67.1)
# Requirement already satisfied: scipy<2,>=1.3 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from openwakeword==0.6.0) (1.13.1)
# Requirement already satisfied: scikit-learn<2,>=1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from openwakeword==0.6.0) (1.7.2)
# Requirement already satisfied: requests<3,>=2.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from openwakeword==0.6.0) (2.32.5)
# Requirement already satisfied: coloredlogs in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from onnxruntime<2,>=1.10.0->openwakeword==0.6.0) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from onnxruntime<2,>=1.10.0->openwakeword==0.6.0) (25.9.23)
# Requirement already satisfied: numpy>=1.21.6 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from onnxruntime<2,>=1.10.0->openwakeword==0.6.0) (2.0.2)
# Requirement already satisfied: packaging in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from onnxruntime<2,>=1.10.0->openwakeword==0.6.0) (25.0)
# Requirement already satisfied: protobuf in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from onnxruntime<2,>=1.10.0->openwakeword==0.6.0) (6.33.0)
# Requirement already satisfied: sympy in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from onnxruntime<2,>=1.10.0->openwakeword==0.6.0) (1.14.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from requests<3,>=2.0->openwakeword==0.6.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from requests<3,>=2.0->openwakeword==0.6.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from requests<3,>=2.0->openwakeword==0.6.0) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from requests<3,>=2.0->openwakeword==0.6.0) (2025.10.5)
# Requirement already satisfied: joblib>=1.2.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from scikit-learn<2,>=1->openwakeword==0.6.0) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from scikit-learn<2,>=1->openwakeword==0.6.0) (3.6.0)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from coloredlogs->onnxruntime<2,>=1.10.0->openwakeword==0.6.0) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from sympy->onnxruntime<2,>=1.10.0->openwakeword==0.6.0) (1.3.0)
# Building wheels for collected packages: openwakeword
#   Building editable for openwakeword (pyproject.toml) ... done
#   Created wheel for openwakeword: filename=openwakeword-0.6.0-0.editable-py3-none-any.whl size=17493 sha256=07fdab6abc5fbcfc2bbcab9323380c1eb754966dbd46694ccf218cf3a928b9fc
#   Stored in directory: /private/var/folders/rf/w8hmc77j7g711fhyb5t40t680000gn/T/pip-ephem-wheel-cache-1fzzo8si/wheels/53/6a/6b/b5f837b0a48bc976015487a91c2b3d63e500005f5504b281a1
# Successfully built openwakeword
# Installing collected packages: openwakeword
#   Attempting uninstall: openwakeword
#     Found existing installation: openwakeword 0.6.0
#     Uninstalling openwakeword-0.6.0:
#       Successfully uninstalled openwakeword-0.6.0
# Successfully installed openwakeword-0.6.0
# Requirement already satisfied: mutagen==1.47.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (1.47.0)
# Requirement already satisfied: torchinfo==1.8.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (1.8.0)
# Requirement already satisfied: torchmetrics==1.2.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (1.2.0)
# Requirement already satisfied: numpy>1.20.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from torchmetrics==1.2.0) (2.0.2)
# Requirement already satisfied: torch>=1.8.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from torchmetrics==1.2.0) (2.9.0)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from torchmetrics==1.2.0) (0.15.2)
# Requirement already satisfied: packaging>=17.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from lightning-utilities>=0.8.0->torchmetrics==1.2.0) (25.0)
# Requirement already satisfied: setuptools in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from lightning-utilities>=0.8.0->torchmetrics==1.2.0) (80.9.0)
# Requirement already satisfied: typing_extensions in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from lightning-utilities>=0.8.0->torchmetrics==1.2.0) (4.15.0)
# Requirement already satisfied: filelock in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from torch>=1.8.1->torchmetrics==1.2.0) (3.20.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from torch>=1.8.1->torchmetrics==1.2.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from torch>=1.8.1->torchmetrics==1.2.0) (3.5)
# Requirement already satisfied: jinja2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from torch>=1.8.1->torchmetrics==1.2.0) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from torch>=1.8.1->torchmetrics==1.2.0) (2024.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=1.8.1->torchmetrics==1.2.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from jinja2->torch>=1.8.1->torchmetrics==1.2.0) (3.0.3)
# Requirement already satisfied: speechbrain==0.5.14 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (0.5.14)
# Requirement already satisfied: hyperpyyaml in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from speechbrain==0.5.14) (1.2.2)
# Requirement already satisfied: joblib in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from speechbrain==0.5.14) (1.5.2)
# Requirement already satisfied: numpy in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from speechbrain==0.5.14) (2.0.2)
# Requirement already satisfied: packaging in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from speechbrain==0.5.14) (25.0)
# Requirement already satisfied: scipy in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from speechbrain==0.5.14) (1.13.1)
# Requirement already satisfied: sentencepiece in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from speechbrain==0.5.14) (0.2.1)
# Requirement already satisfied: torch>=1.9 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from speechbrain==0.5.14) (2.9.0)
# Requirement already satisfied: torchaudio in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from speechbrain==0.5.14) (2.9.0)
# Requirement already satisfied: tqdm in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from speechbrain==0.5.14) (4.67.1)
# Requirement already satisfied: huggingface-hub in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from speechbrain==0.5.14) (0.36.0)
# Requirement already satisfied: filelock in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from torch>=1.9->speechbrain==0.5.14) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from torch>=1.9->speechbrain==0.5.14) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from torch>=1.9->speechbrain==0.5.14) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from torch>=1.9->speechbrain==0.5.14) (3.5)
# Requirement already satisfied: jinja2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from torch>=1.9->speechbrain==0.5.14) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from torch>=1.9->speechbrain==0.5.14) (2024.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=1.9->speechbrain==0.5.14) (1.3.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from huggingface-hub->speechbrain==0.5.14) (6.0.3)
# Requirement already satisfied: requests in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from huggingface-hub->speechbrain==0.5.14) (2.32.5)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from huggingface-hub->speechbrain==0.5.14) (1.1.10)
# Requirement already satisfied: ruamel.yaml>=0.17.28 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from hyperpyyaml->speechbrain==0.5.14) (0.18.16)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from ruamel.yaml>=0.17.28->hyperpyyaml->speechbrain==0.5.14) (0.2.14)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from jinja2->torch>=1.9->speechbrain==0.5.14) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from requests->huggingface-hub->speechbrain==0.5.14) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from requests->huggingface-hub->speechbrain==0.5.14) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from requests->huggingface-hub->speechbrain==0.5.14) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from requests->huggingface-hub->speechbrain==0.5.14) (2025.10.5)
# Requirement already satisfied: audiomentations==0.33.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (0.33.0)
# Requirement already satisfied: numpy>=1.18.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from audiomentations==0.33.0) (2.0.2)
# Requirement already satisfied: librosa!=0.10.0,<0.11.0,>=0.8.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from audiomentations==0.33.0) (0.10.2.post1)
# Requirement already satisfied: scipy<2,>=1.4.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from audiomentations==0.33.0) (1.13.1)
# Requirement already satisfied: soxr<1.0.0,>=0.3.2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from audiomentations==0.33.0) (0.5.0.post1)
# Requirement already satisfied: audioread>=2.1.9 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (3.0.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (1.7.2)
# Requirement already satisfied: joblib>=0.14 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (1.5.2)
# Requirement already satisfied: decorator>=4.3.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (5.2.1)
# Requirement already satisfied: numba>=0.51.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (0.62.1)
# Requirement already satisfied: soundfile>=0.12.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (1.8.2)
# Requirement already satisfied: typing-extensions>=4.1.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (4.15.0)
# Requirement already satisfied: lazy-loader>=0.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (1.1.2)
# Requirement already satisfied: packaging in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from lazy-loader>=0.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (25.0)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from numba>=0.51.0->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (0.45.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from pooch>=1.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (4.5.0)
# Requirement already satisfied: requests>=2.19.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from pooch>=1.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (2025.10.5)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from scikit-learn>=0.20.0->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from soundfile>=0.12.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (2.0.0)
# Requirement already satisfied: pycparser in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (2.23)
# Requirement already satisfied: torch-audiomentations==0.11.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (0.11.0)
# Requirement already satisfied: julius<0.3,>=0.2.3 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from torch-audiomentations==0.11.0) (0.2.7)
# Requirement already satisfied: librosa>=0.6.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from torch-audiomentations==0.11.0) (0.10.2.post1)
# Requirement already satisfied: torch>=1.7.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from torch-audiomentations==0.11.0) (2.9.0)
# Requirement already satisfied: torchaudio>=0.7.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from torch-audiomentations==0.11.0) (2.9.0)
# Requirement already satisfied: torch-pitch-shift>=1.2.2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from torch-audiomentations==0.11.0) (1.2.5)
# Requirement already satisfied: audioread>=2.1.9 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (2.0.2)
# Requirement already satisfied: scipy>=1.2.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (1.7.2)
# Requirement already satisfied: joblib>=0.14 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (1.5.2)
# Requirement already satisfied: decorator>=4.3.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (5.2.1)
# Requirement already satisfied: numba>=0.51.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (0.62.1)
# Requirement already satisfied: soundfile>=0.12.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (0.5.0.post1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (4.15.0)
# Requirement already satisfied: lazy-loader>=0.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (1.1.2)
# Requirement already satisfied: packaging in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from lazy-loader>=0.1->librosa>=0.6.0->torch-audiomentations==0.11.0) (25.0)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from numba>=0.51.0->librosa>=0.6.0->torch-audiomentations==0.11.0) (0.45.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from pooch>=1.1->librosa>=0.6.0->torch-audiomentations==0.11.0) (4.5.0)
# Requirement already satisfied: requests>=2.19.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from pooch>=1.1->librosa>=0.6.0->torch-audiomentations==0.11.0) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.1->librosa>=0.6.0->torch-audiomentations==0.11.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.1->librosa>=0.6.0->torch-audiomentations==0.11.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.1->librosa>=0.6.0->torch-audiomentations==0.11.0) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.1->librosa>=0.6.0->torch-audiomentations==0.11.0) (2025.10.5)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from scikit-learn>=0.20.0->librosa>=0.6.0->torch-audiomentations==0.11.0) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from soundfile>=0.12.1->librosa>=0.6.0->torch-audiomentations==0.11.0) (2.0.0)
# Requirement already satisfied: pycparser in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa>=0.6.0->torch-audiomentations==0.11.0) (2.23)
# Requirement already satisfied: filelock in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from torch>=1.7.0->torch-audiomentations==0.11.0) (3.20.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from torch>=1.7.0->torch-audiomentations==0.11.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from torch>=1.7.0->torch-audiomentations==0.11.0) (3.5)
# Requirement already satisfied: jinja2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from torch>=1.7.0->torch-audiomentations==0.11.0) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from torch>=1.7.0->torch-audiomentations==0.11.0) (2024.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=1.7.0->torch-audiomentations==0.11.0) (1.3.0)
# Requirement already satisfied: primePy>=1.3 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from torch-pitch-shift>=1.2.2->torch-audiomentations==0.11.0) (1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from jinja2->torch>=1.7.0->torch-audiomentations==0.11.0) (3.0.3)
# Requirement already satisfied: acoustics==0.2.6 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (0.2.6)
# Requirement already satisfied: numpy>=1.8 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from acoustics==0.2.6) (2.0.2)
# Requirement already satisfied: scipy>=0.16 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from acoustics==0.2.6) (1.13.1)
# Requirement already satisfied: matplotlib in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from acoustics==0.2.6) (3.10.7)
# Requirement already satisfied: six>=1.4.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from acoustics==0.2.6) (1.17.0)
# Requirement already satisfied: pandas>=0.15 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from acoustics==0.2.6) (2.3.3)
# Requirement already satisfied: tabulate in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from acoustics==0.2.6) (0.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from pandas>=0.15->acoustics==0.2.6) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from pandas>=0.15->acoustics==0.2.6) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from pandas>=0.15->acoustics==0.2.6) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from matplotlib->acoustics==0.2.6) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from matplotlib->acoustics==0.2.6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from matplotlib->acoustics==0.2.6) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from matplotlib->acoustics==0.2.6) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from matplotlib->acoustics==0.2.6) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from matplotlib->acoustics==0.2.6) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from matplotlib->acoustics==0.2.6) (3.2.5)
# ERROR: Could not find a version that satisfies the requirement tensorflow-cpu==2.8.1 (from versions: none)
# ERROR: No matching distribution found for tensorflow-cpu==2.8.1
# Requirement already satisfied: tensorflow_probability==0.16.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (0.16.0)
# Requirement already satisfied: absl-py in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from tensorflow_probability==0.16.0) (2.3.1)
# Requirement already satisfied: six>=1.10.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from tensorflow_probability==0.16.0) (1.17.0)
# Requirement already satisfied: numpy>=1.13.3 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from tensorflow_probability==0.16.0) (2.0.2)
# Requirement already satisfied: decorator in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from tensorflow_probability==0.16.0) (5.2.1)
# Requirement already satisfied: cloudpickle>=1.3 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from tensorflow_probability==0.16.0) (3.1.1)
# Requirement already satisfied: gast>=0.3.2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from tensorflow_probability==0.16.0) (0.6.0)
# Requirement already satisfied: dm-tree in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from tensorflow_probability==0.16.0) (0.1.9)
# Requirement already satisfied: attrs>=18.2.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from dm-tree->tensorflow_probability==0.16.0) (25.4.0)
# Requirement already satisfied: wrapt>=1.11.2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from dm-tree->tensorflow_probability==0.16.0) (2.0.0)
# Requirement already satisfied: onnx_tf==1.10.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (1.10.0)
# Requirement already satisfied: onnx>=1.10.2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from onnx_tf==1.10.0) (1.19.1)
# Requirement already satisfied: PyYAML in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from onnx_tf==1.10.0) (6.0.3)
# Requirement already satisfied: tensorflow-addons in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from onnx_tf==1.10.0) (0.23.0)
# Requirement already satisfied: numpy>=1.22 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from onnx>=1.10.2->onnx_tf==1.10.0) (2.0.2)
# Requirement already satisfied: protobuf>=4.25.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from onnx>=1.10.2->onnx_tf==1.10.0) (6.33.0)
# Requirement already satisfied: typing_extensions>=4.7.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from onnx>=1.10.2->onnx_tf==1.10.0) (4.15.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from onnx>=1.10.2->onnx_tf==1.10.0) (0.5.3)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from tensorflow-addons->onnx_tf==1.10.0) (2.13.3)
# Requirement already satisfied: packaging in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from tensorflow-addons->onnx_tf==1.10.0) (25.0)
# Requirement already satisfied: pronouncing==0.2.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (0.2.0)
# Requirement already satisfied: cmudict>=0.4.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from pronouncing==0.2.0) (1.1.1)
# Requirement already satisfied: importlib-metadata>=5 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from cmudict>=0.4.0->pronouncing==0.2.0) (8.7.0)
# Requirement already satisfied: importlib-resources>=5 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from cmudict>=0.4.0->pronouncing==0.2.0) (6.5.2)
# Requirement already satisfied: zipp>=3.20 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from importlib-metadata>=5->cmudict>=0.4.0->pronouncing==0.2.0) (3.23.0)
# Requirement already satisfied: datasets in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (2.20.0)
# Requirement already satisfied: filelock in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from datasets) (3.20.0)
# Requirement already satisfied: numpy>=1.17 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from datasets) (21.0.0)
# Requirement already satisfied: pyarrow-hotfix in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from datasets) (0.7)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from datasets) (2.3.3)
# Requirement already satisfied: requests>=2.32.2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from datasets) (2.32.5)
# Requirement already satisfied: tqdm>=4.66.3 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.5.0,>=2023.1.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from fsspec[http]<=2024.5.0,>=2023.1.0->datasets) (2024.5.0)
# Requirement already satisfied: aiohttp in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from datasets) (3.13.1)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from datasets) (0.36.0)
# Requirement already satisfied: packaging in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from aiohttp->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from aiohttp->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from aiohttp->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from aiohttp->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from aiohttp->datasets) (1.22.0)
# Requirement already satisfied: idna>=2.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from yarl<2.0,>=1.17.0->aiohttp->datasets) (3.11)
# Requirement already satisfied: typing-extensions>=4.2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from aiosignal>=1.4.0->aiohttp->datasets) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from huggingface-hub>=0.21.2->datasets) (1.1.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (2025.10.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: deep-phonemizer==0.0.19 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (0.0.19)
# Requirement already satisfied: torch>=1.2.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from deep-phonemizer==0.0.19) (2.9.0)
# Requirement already satisfied: tqdm>=4.38.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from deep-phonemizer==0.0.19) (4.67.1)
# Requirement already satisfied: PyYAML>=5.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from deep-phonemizer==0.0.19) (6.0.3)
# Requirement already satisfied: tensorboard in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from deep-phonemizer==0.0.19) (2.20.0)
# Requirement already satisfied: certifi>=2022.12.7 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from deep-phonemizer==0.0.19) (2025.10.5)
# Requirement already satisfied: wheel>=0.38.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from deep-phonemizer==0.0.19) (0.45.1)
# Requirement already satisfied: setuptools>=65.5.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from deep-phonemizer==0.0.19) (80.9.0)
# Requirement already satisfied: filelock in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from torch>=1.2.0->deep-phonemizer==0.0.19) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from torch>=1.2.0->deep-phonemizer==0.0.19) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from torch>=1.2.0->deep-phonemizer==0.0.19) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from torch>=1.2.0->deep-phonemizer==0.0.19) (3.5)
# Requirement already satisfied: jinja2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from torch>=1.2.0->deep-phonemizer==0.0.19) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from torch>=1.2.0->deep-phonemizer==0.0.19) (2024.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=1.2.0->deep-phonemizer==0.0.19) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from jinja2->torch>=1.2.0->deep-phonemizer==0.0.19) (3.0.3)
# Requirement already satisfied: absl-py>=0.4 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from tensorboard->deep-phonemizer==0.0.19) (2.3.1)
# Requirement already satisfied: grpcio>=1.48.2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from tensorboard->deep-phonemizer==0.0.19) (1.62.2)
# Requirement already satisfied: markdown>=2.6.8 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from tensorboard->deep-phonemizer==0.0.19) (3.9)
# Requirement already satisfied: numpy>=1.12.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from tensorboard->deep-phonemizer==0.0.19) (2.0.2)
# Requirement already satisfied: packaging in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from tensorboard->deep-phonemizer==0.0.19) (25.0)
# Requirement already satisfied: pillow in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from tensorboard->deep-phonemizer==0.0.19) (12.0.0)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from tensorboard->deep-phonemizer==0.0.19) (6.33.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from tensorboard->deep-phonemizer==0.0.19) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from tensorboard->deep-phonemizer==0.0.19) (3.1.3)
# --2025-10-23 19:53:15--  https://github.com/dscripka/openWakeWord/releases/download/v0.5.1/embedding_model.onnx
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/497407399/0233db07-b8db-4fc3-b026-b75d77fd7ae6?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-10-24T01%3A28%3A03Z&rscd=attachment%3B+filename%3Dembedding_model.onnx&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-10-24T00%3A28%3A01Z&ske=2025-10-24T01%3A28%3A03Z&sks=b&skv=2018-11-09&sig=QegY52NztKllBuR9E5gywwJ2pA5xNDUZEdYvfwNLF%2Bc%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2MTI2NzQ5NSwibmJmIjoxNzYxMjY3MTk1LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.GI_dgOlP43SfuCxkE8PeNVUUhPqdwvwgLeKI9lDzYLo&response-content-disposition=attachment%3B%20filename%3Dembedding_model.onnx&response-content-type=application%2Foctet-stream [following]
# --2025-10-23 19:53:15--  https://release-assets.githubusercontent.com/github-production-release-asset/497407399/0233db07-b8db-4fc3-b026-b75d77fd7ae6?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-10-24T01%3A28%3A03Z&rscd=attachment%3B+filename%3Dembedding_model.onnx&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-10-24T00%3A28%3A01Z&ske=2025-10-24T01%3A28%3A03Z&sks=b&skv=2018-11-09&sig=QegY52NztKllBuR9E5gywwJ2pA5xNDUZEdYvfwNLF%2Bc%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2MTI2NzQ5NSwibmJmIjoxNzYxMjY3MTk1LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.GI_dgOlP43SfuCxkE8PeNVUUhPqdwvwgLeKI9lDzYLo&response-content-disposition=attachment%3B%20filename%3Dembedding_model.onnx&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1326578 (1.3M) [application/octet-stream]
# Saving to: ‘./openwakeword/openwakeword/resources/models/embedding_model.onnx’
#
# ./openwakeword/open 100%[===================>]   1.26M  --.-KB/s    in 0.07s
#
# 2025-10-23 19:53:15 (19.0 MB/s) - ‘./openwakeword/openwakeword/resources/models/embedding_model.onnx’ saved [1326578/1326578]
#
# --2025-10-23 19:53:16--  https://github.com/dscripka/openWakeWord/releases/download/v0.5.1/embedding_model.tflite
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/497407399/4bfa8f05-dd30-45f6-b47c-c55548bb5ffc?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-10-24T01%3A53%3A03Z&rscd=attachment%3B+filename%3Dembedding_model.tflite&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-10-24T00%3A52%3A19Z&ske=2025-10-24T01%3A53%3A03Z&sks=b&skv=2018-11-09&sig=hjYtfSS4cSQ3Axd9s8ys28WxfTwnAUFFg7TCWHo8Nrs%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2MTI2NzQ5NiwibmJmIjoxNzYxMjY3MTk2LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.e7zbDHX7rt3cfTfDari0zAVUsQxgQobugimFY0c1Mq4&response-content-disposition=attachment%3B%20filename%3Dembedding_model.tflite&response-content-type=application%2Foctet-stream [following]
# --2025-10-23 19:53:16--  https://release-assets.githubusercontent.com/github-production-release-asset/497407399/4bfa8f05-dd30-45f6-b47c-c55548bb5ffc?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-10-24T01%3A53%3A03Z&rscd=attachment%3B+filename%3Dembedding_model.tflite&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-10-24T00%3A52%3A19Z&ske=2025-10-24T01%3A53%3A03Z&sks=b&skv=2018-11-09&sig=hjYtfSS4cSQ3Axd9s8ys28WxfTwnAUFFg7TCWHo8Nrs%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2MTI2NzQ5NiwibmJmIjoxNzYxMjY3MTk2LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.e7zbDHX7rt3cfTfDari0zAVUsQxgQobugimFY0c1Mq4&response-content-disposition=attachment%3B%20filename%3Dembedding_model.tflite&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1330312 (1.3M) [application/octet-stream]
# Saving to: ‘./openwakeword/openwakeword/resources/models/embedding_model.tflite’
#
# ./openwakeword/open 100%[===================>]   1.27M  --.-KB/s    in 0.07s
#
# 2025-10-23 19:53:16 (17.9 MB/s) - ‘./openwakeword/openwakeword/resources/models/embedding_model.tflite’ saved [1330312/1330312]
#
# --2025-10-23 19:53:16--  https://github.com/dscripka/openWakeWord/releases/download/v0.5.1/melspectrogram.onnx
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/497407399/6b613c12-b693-4220-82d5-01be396893d9?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-10-24T01%3A52%3A47Z&rscd=attachment%3B+filename%3Dmelspectrogram.onnx&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-10-24T00%3A52%3A07Z&ske=2025-10-24T01%3A52%3A47Z&sks=b&skv=2018-11-09&sig=gt7sT%2Fsn268WKvl6YsR24qFGs4ixF0mzUNdV7igg%2FSs%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2MTI2NzQ5NiwibmJmIjoxNzYxMjY3MTk2LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.e7zbDHX7rt3cfTfDari0zAVUsQxgQobugimFY0c1Mq4&response-content-disposition=attachment%3B%20filename%3Dmelspectrogram.onnx&response-content-type=application%2Foctet-stream [following]
# --2025-10-23 19:53:16--  https://release-assets.githubusercontent.com/github-production-release-asset/497407399/6b613c12-b693-4220-82d5-01be396893d9?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-10-24T01%3A52%3A47Z&rscd=attachment%3B+filename%3Dmelspectrogram.onnx&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-10-24T00%3A52%3A07Z&ske=2025-10-24T01%3A52%3A47Z&sks=b&skv=2018-11-09&sig=gt7sT%2Fsn268WKvl6YsR24qFGs4ixF0mzUNdV7igg%2FSs%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2MTI2NzQ5NiwibmJmIjoxNzYxMjY3MTk2LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.e7zbDHX7rt3cfTfDari0zAVUsQxgQobugimFY0c1Mq4&response-content-disposition=attachment%3B%20filename%3Dmelspectrogram.onnx&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1087958 (1.0M) [application/octet-stream]
# Saving to: ‘./openwakeword/openwakeword/resources/models/melspectrogram.onnx’
#
# ./openwakeword/open 100%[===================>]   1.04M  --.-KB/s    in 0.06s
#
# 2025-10-23 19:53:17 (16.5 MB/s) - ‘./openwakeword/openwakeword/resources/models/melspectrogram.onnx’ saved [1087958/1087958]
#
# --2025-10-23 19:53:17--  https://github.com/dscripka/openWakeWord/releases/download/v0.5.1/melspectrogram.tflite
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/497407399/14a5e610-f7fa-4157-ae44-fdaabf875683?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-10-24T01%3A53%3A22Z&rscd=attachment%3B+filename%3Dmelspectrogram.tflite&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-10-24T00%3A52%3A41Z&ske=2025-10-24T01%3A53%3A22Z&sks=b&skv=2018-11-09&sig=nYMx0vKHDkB%2FF4wK9TgbAC5nYOhkwliM%2FDguBdiX6Vw%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2MTI2NzQ5NywibmJmIjoxNzYxMjY3MTk3LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.AKjTC60YZClhhjDv_I-h4wfVOR8hj4GH37hDpJjigvY&response-content-disposition=attachment%3B%20filename%3Dmelspectrogram.tflite&response-content-type=application%2Foctet-stream [following]
# --2025-10-23 19:53:17--  https://release-assets.githubusercontent.com/github-production-release-asset/497407399/14a5e610-f7fa-4157-ae44-fdaabf875683?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-10-24T01%3A53%3A22Z&rscd=attachment%3B+filename%3Dmelspectrogram.tflite&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-10-24T00%3A52%3A41Z&ske=2025-10-24T01%3A53%3A22Z&sks=b&skv=2018-11-09&sig=nYMx0vKHDkB%2FF4wK9TgbAC5nYOhkwliM%2FDguBdiX6Vw%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2MTI2NzQ5NywibmJmIjoxNzYxMjY3MTk3LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.AKjTC60YZClhhjDv_I-h4wfVOR8hj4GH37hDpJjigvY&response-content-disposition=attachment%3B%20filename%3Dmelspectrogram.tflite&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1092516 (1.0M) [application/octet-stream]
# Saving to: ‘./openwakeword/openwakeword/resources/models/melspectrogram.tflite’
#
# ./openwakeword/open 100%[===================>]   1.04M  --.-KB/s    in 0.06s
#
# 2025-10-23 19:53:17 (17.5 MB/s) - ‘./openwakeword/openwakeword/resources/models/melspectrogram.tflite’ saved [1092516/1092516]

# %%
# Imports
import os
import numpy as np
import torch
import sys
from pathlib import Path
import uuid
import yaml
import datasets
import scipy
from tqdm import tqdm

# %%
# Install requirements (it's recommended that you do this in a new virtual environment)

# !pip install openwakeword
# !pip install speechbrain
# !pip install datasets
# !pip install scipy matplotlib
# Out:
# Requirement already satisfied: openwakeword in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (0.6.0)
# Requirement already satisfied: onnxruntime<2,>=1.10.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from openwakeword) (1.23.2)
# Requirement already satisfied: tqdm<5.0,>=4.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from openwakeword) (4.67.1)
# Requirement already satisfied: scipy<2,>=1.3 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from openwakeword) (1.13.1)
# Requirement already satisfied: scikit-learn<2,>=1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from openwakeword) (1.7.2)
# Requirement already satisfied: requests<3,>=2.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from openwakeword) (2.32.5)
# Requirement already satisfied: coloredlogs in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from onnxruntime<2,>=1.10.0->openwakeword) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from onnxruntime<2,>=1.10.0->openwakeword) (25.9.23)
# Requirement already satisfied: numpy>=1.21.6 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from onnxruntime<2,>=1.10.0->openwakeword) (2.0.2)
# Requirement already satisfied: packaging in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from onnxruntime<2,>=1.10.0->openwakeword) (25.0)
# Requirement already satisfied: protobuf in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from onnxruntime<2,>=1.10.0->openwakeword) (6.33.0)
# Requirement already satisfied: sympy in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from onnxruntime<2,>=1.10.0->openwakeword) (1.14.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from requests<3,>=2.0->openwakeword) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from requests<3,>=2.0->openwakeword) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from requests<3,>=2.0->openwakeword) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from requests<3,>=2.0->openwakeword) (2025.10.5)
# Requirement already satisfied: joblib>=1.2.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from scikit-learn<2,>=1->openwakeword) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from scikit-learn<2,>=1->openwakeword) (3.6.0)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from coloredlogs->onnxruntime<2,>=1.10.0->openwakeword) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from sympy->onnxruntime<2,>=1.10.0->openwakeword) (1.3.0)
# Requirement already satisfied: speechbrain in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (0.5.14)
# Requirement already satisfied: hyperpyyaml in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from speechbrain) (1.2.2)
# Requirement already satisfied: joblib in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from speechbrain) (1.5.2)
# Requirement already satisfied: numpy in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from speechbrain) (2.0.2)
# Requirement already satisfied: packaging in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from speechbrain) (25.0)
# Requirement already satisfied: scipy in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from speechbrain) (1.13.1)
# Requirement already satisfied: sentencepiece in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from speechbrain) (0.2.1)
# Requirement already satisfied: torch>=1.9 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from speechbrain) (2.9.0)
# Requirement already satisfied: torchaudio in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from speechbrain) (2.9.0)
# Requirement already satisfied: tqdm in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from speechbrain) (4.67.1)
# Requirement already satisfied: huggingface-hub in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from speechbrain) (0.36.0)
# Requirement already satisfied: filelock in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from torch>=1.9->speechbrain) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from torch>=1.9->speechbrain) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from torch>=1.9->speechbrain) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from torch>=1.9->speechbrain) (3.5)
# Requirement already satisfied: jinja2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from torch>=1.9->speechbrain) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from torch>=1.9->speechbrain) (2024.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=1.9->speechbrain) (1.3.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from huggingface-hub->speechbrain) (6.0.3)
# Requirement already satisfied: requests in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from huggingface-hub->speechbrain) (2.32.5)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from huggingface-hub->speechbrain) (1.1.10)
# Requirement already satisfied: ruamel.yaml>=0.17.28 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from hyperpyyaml->speechbrain) (0.18.16)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from ruamel.yaml>=0.17.28->hyperpyyaml->speechbrain) (0.2.14)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from jinja2->torch>=1.9->speechbrain) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from requests->huggingface-hub->speechbrain) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from requests->huggingface-hub->speechbrain) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from requests->huggingface-hub->speechbrain) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from requests->huggingface-hub->speechbrain) (2025.10.5)
# Requirement already satisfied: datasets in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (2.20.0)
# Requirement already satisfied: filelock in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from datasets) (3.20.0)
# Requirement already satisfied: numpy>=1.17 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from datasets) (21.0.0)
# Requirement already satisfied: pyarrow-hotfix in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from datasets) (0.7)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from datasets) (2.3.3)
# Requirement already satisfied: requests>=2.32.2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from datasets) (2.32.5)
# Requirement already satisfied: tqdm>=4.66.3 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.5.0,>=2023.1.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from fsspec[http]<=2024.5.0,>=2023.1.0->datasets) (2024.5.0)
# Requirement already satisfied: aiohttp in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from datasets) (3.13.1)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from datasets) (0.36.0)
# Requirement already satisfied: packaging in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from aiohttp->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from aiohttp->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from aiohttp->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from aiohttp->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from aiohttp->datasets) (1.22.0)
# Requirement already satisfied: idna>=2.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from yarl<2.0,>=1.17.0->aiohttp->datasets) (3.11)
# Requirement already satisfied: typing-extensions>=4.2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from aiosignal>=1.4.0->aiohttp->datasets) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from huggingface-hub>=0.21.2->datasets) (1.1.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (2025.10.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: scipy in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (1.13.1)
# Requirement already satisfied: matplotlib in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (3.10.7)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from scipy) (2.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %% [markdown]
# # Download Data

# %% [markdown]
# When training new openWakeWord models using the automated procedure, four specific types of data are required:
#
# 1) Synthetic examples of the target word/phrase generated with text-to-speech models
#
# 2) Synthetic examples of adversarial words/phrases generated with text-to-speech models
#
# 3) Room impulse reponses and noise/background audio data to augment the synthetic examples and make them more realistic
#
# 4) Generic "negative" audio data that is very unlikely to contain examples of the target word/phrase in the context where the model should detect it. This data can be the original audio data, or precomputed openWakeWord features ready for model training.
#
# 5) Validation data to use for early-stopping when training the model.
#
# For the purposes of this notebook, all five of these sources will either be generated manually or can be obtained from HuggingFace thanks to their excellent `datasets` library and extremely generous hosting policy. Also note that while only a portion of some datasets are downloaded, for the best possible performance it is recommended to download the entire dataset and keep a local copy for future training runs.

# %%
# Download room impulse responses collected by MIT
# https://mcdermottlab.mit.edu/Reverb/IR_Survey.html

output_dir = "./mit_rirs"
if not os.path.exists(output_dir):
    os.mkdir(output_dir)
rir_dataset = datasets.load_dataset("davidscripka/MIT_environmental_impulse_responses", split="train", streaming=True)

# Save clips to 16-bit PCM wav files
for row in tqdm(rir_dataset):
    name = row['audio']['path'].split('/')[-1]
    scipy.io.wavfile.write(os.path.join(output_dir, name), 16000, (row['audio']['array']*32767).astype(np.int16))
# Out:
# Downloading readme: 100%|██████████| 936/936 [00:00<00:00, 4.31MB/s]
# 270it [00:54,  4.94it/s]

# %%
from datasets import load_dataset, Audio
import os, scipy.io.wavfile as wav

os.makedirs("./fma", exist_ok=True)

# download locally so files are seekable
fma = load_dataset("rudraml/fma", name="small", split="train", streaming=False)
fma = fma.cast_column("audio", Audio(sampling_rate=16000))

n_hours = 1
n_files = n_hours * 3600 // 30  # FMA-small clips are 30s
for i, row in enumerate(fma.select(range(n_files))):
    name = row["audio"]["path"].split("/")[-1].replace(".mp3", ".wav")
    wav.write(os.path.join("./fma", name), 16000, (row["audio"]["array"] * 32767).astype("int16"))
# Out:
# Downloading data: 100%|██████████| 358M/358M [01:43<00:00, 3.45MB/s]

# %%
## Download noise and background audio

# Audioset Dataset (https://research.google.com/audioset/dataset/index.html)
# Download one part of the audioset .tar files, extract, and convert to 16khz
# For full-scale training, it's recommended to download the entire dataset from
# https://huggingface.co/datasets/agkphysics/AudioSet, and
# even potentially combine it with other background noise datasets (e.g., FSD50k, Freesound, etc.)

if not os.path.exists("audioset"):
    os.mkdir("audioset")

fname = "bal_train09.tar"
out_dir = f"audioset/{fname}"
link = "https://huggingface.co/datasets/agkphysics/AudioSet/resolve/main/data/" + fname
# !wget -O {out_dir} {link}
# !cd audioset && tar -xvf bal_train09.tar

output_dir = "./audioset_16k"
if not os.path.exists(output_dir):
    os.mkdir(output_dir)

# Convert audioset files to 16khz sample rate
audioset_dataset = datasets.Dataset.from_dict({"audio": [str(i) for i in Path("audioset/audio").glob("**/*.flac")]})
audioset_dataset = audioset_dataset.cast_column("audio", datasets.Audio(sampling_rate=16000))
for row in tqdm(audioset_dataset):
    name = row['audio']['path'].split('/')[-1].replace(".flac", ".wav")
    scipy.io.wavfile.write(os.path.join(output_dir, name), 16000, (row['audio']['array']*32767).astype(np.int16))

# Free Music Archive dataset (https://github.com/mdeff/fma)
output_dir = "./fma"
if not os.path.exists(output_dir):
    os.mkdir(output_dir)
fma_dataset = datasets.load_dataset("rudraml/fma", name="small", split="train", streaming=True)
fma_dataset = iter(fma_dataset.cast_column("audio", datasets.Audio(sampling_rate=16000)))

n_hours = 1  # use only 1 hour of clips for this example notebook, recommend increasing for full-scale training
for i in tqdm(range(n_hours*3600//30)):  # this works because the FMA dataset is all 30 second clips
    row = next(fma_dataset)
    name = row['audio']['path'].split('/')[-1].replace(".mp3", ".wav")
    scipy.io.wavfile.write(os.path.join(output_dir, name), 16000, (row['audio']['array']*32767).astype(np.int16))
    i += 1
    if i == n_hours*3600//30:
        break
# Out:
# --2025-10-23 20:01:21--  https://huggingface.co/datasets/agkphysics/AudioSet/resolve/main/data/bal_train09.tar
# Resolving huggingface.co (huggingface.co)... 52.84.217.88, 52.84.217.69, 52.84.217.103, ...
# Connecting to huggingface.co (huggingface.co)|52.84.217.88|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-10-23 20:01:21 ERROR 404: Not Found.
# 0it [00:00, ?it/s]
# Downloading builder script: 46.3kB [00:00, 57.9MB/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 33
#      31 if not os.path.exists(output_dir):
#      32     os.mkdir(output_dir)
# ---> 33 fma_dataset = datasets.load_dataset("rudraml/fma", name="small", split="train", streaming=True)
#      34 fma_dataset = iter(fma_dataset.cast_column("audio", datasets.Audio(sampling_rate=16000)))
#      36 n_hours = 1  # use only 1 hour of clips for this example notebook, recommend increasing for full-scale training
#
# File ~/crackle_ws/crackle/.venv/lib/python3.9/site-packages/datasets/load.py:2613, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, ignore_verifications, keep_in_memory, save_infos, revision, token, use_auth_token, task, streaming, num_proc, storage_options, trust_remote_code, **config_kwargs)
#    2611 # Return iterable dataset in case of streaming
#    2612 if streaming:
# -> 2613     return builder_instance.as_streaming_dataset(split=split)
#    2615 # Download and prepare data
#    2616 builder_instance.download_and_prepare(
#    2617     download_config=download_config,
#    2618     download_mode=download_mode,
#    (...)
#    2621     storage_options=storage_options,
#    2622 )
#
# File ~/crackle_ws/crackle/.venv/lib/python3.9/site-packages/datasets/builder.py:1406, in DatasetBuilder.as_streaming_dataset(self, split, base_path)
#    1399 dl_manager = StreamingDownloadManager(
#    1400     base_path=base_path or self.base_path,
#    1401     download_config=DownloadConfig(token=self.token, storage_options=self.storage_options),
#    1402     dataset_name=self.dataset_name,
#    1403     data_dir=self.config.data_dir,
#    1404 )
#    1405 self._check_manual_download(dl_manager)
# -> 1406 splits_generators = {sg.name: sg for sg in self._split_generators(dl_manager)}
#    1407 # By default, return all splits
#    1408 if split is None:
#
# File ~/.cache/huggingface/modules/datasets_modules/datasets/rudraml--fma/f4dff008b8cc8b8b181272a5bd353024e4abfcda62de876de672f135cf097c0e/fma.py:1024, in FMADataset._split_generators(self, dl_manager)
#    1022 metadata = dl_manager.download(dataset_links["metadata"])
#    1023 metadata = dl_manager.iter_archive(metadata)
# -> 1024 for f in metadata:
#    1025     if f[0] == "fma_metadata/tracks.csv":
#    1026         tracks = utils_load(*f)
#
# File ~/crackle_ws/crackle/.venv/lib/python3.9/site-packages/datasets/utils/file_utils.py:1577, in _IterableFromGenerator.__iter__(self)
#    1576 def __iter__(self):
# -> 1577     for x in self.generator(*self.args, **self.kwargs):
#    1578         self.last_item = x
#    1579         yield x
#
# File ~/crackle_ws/crackle/.venv/lib/python3.9/site-packages/datasets/utils/file_utils.py:1635, in ArchiveIterable._iter_from_urlpath(cls, urlpath, download_config)
#    1633 with xopen(urlpath, "rb", download_config=download_config, block_size=0) as f:
#    1634     if compression == "zip":
# -> 1635         yield from cls._iter_zip(f)
#    1636     else:
#    1637         yield from cls._iter_tar(f)
#
# File ~/crackle_ws/crackle/.venv/lib/python3.9/site-packages/datasets/utils/file_utils.py:1605, in ArchiveIterable._iter_zip(f)
#    1603 @staticmethod
#    1604 def _iter_zip(f):
# -> 1605     zipf = zipfile.ZipFile(f)
#    1606     for member in zipf.infolist():
#    1607         file_path = member.filename
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/zipfile.py:1257, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1255 try:
#    1256     if mode == 'r':
# -> 1257         self._RealGetContents()
#    1258     elif mode in ('w', 'x'):
#    1259         # set the modified flag so central directory gets written
#    1260         # even if no files are added to the archive
#    1261         self._didModify = True
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/zipfile.py:1320, in ZipFile._RealGetContents(self)
#    1318 fp = self.fp
#    1319 try:
# -> 1320     endrec = _EndRecData(fp)
#    1321 except OSError:
#    1322     raise BadZipFile("File is not a zip file")
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/zipfile.py:263, in _EndRecData(fpin)
#     257 """Return data from the "End of Central Directory" record, or None.
#     258
#     259 The data is a list of the nine items in the ZIP "End of central dir"
#     260 record followed by a tenth item, the file seek offset of this record."""
#     262 # Determine file size
# --> 263 fpin.seek(0, 2)
#     264 filesize = fpin.tell()
#     266 # Check to see if this is ZIP file with no archive comment (the
#     267 # "end of central directory" structure should be the last item in the
#     268 # file if this is the case).
#
# File ~/crackle_ws/crackle/.venv/lib/python3.9/site-packages/fsspec/implementations/http.py:759, in HTTPStreamFile.seek(self, loc, whence)
#     757 if loc == self.loc and whence == 0:
#     758     return
# --> 759 raise ValueError("Cannot seek streaming HTTP file")
#
# ValueError: Cannot seek streaming HTTP file

# %%
# Download pre-computed openWakeWord features for training and validation

# training set (~2,000 hours from the ACAV100M Dataset)
# See https://huggingface.co/datasets/davidscripka/openwakeword_features for more information
# !wget https://huggingface.co/datasets/davidscripka/openwakeword_features/resolve/main/openwakeword_features_ACAV100M_2000_hrs_16bit.npy

# validation set for false positive rate estimation (~11 hours)
# !wget https://huggingface.co/datasets/davidscripka/openwakeword_features/resolve/main/validation_set_features.npy

# %% [markdown]
# # Define Training Configuration

# %% [markdown]
# For automated model training openWakeWord uses a specially designed training script and a [YAML](https://yaml.org/) configuration file that defines all of the information required for training a new wake word/phrase detection model.
#
# It is strongly recommended that you review [the example config file](../examples/custom_model.yml), as each value is fully documented there. For the purposes of this notebook, we'll read in the YAML file to modify certain configuration parameters before saving a new YAML file for training our example model. Specifically:
#
# - We'll train a detection model for the phrase "hey sebastian"
# - We'll only generate 5,000 positive and negative examples (to save on time for this example)
# - We'll only generate 1,000 validation positive and negative examples for early stopping (again to save time)
# - The model will only be trained for 10,000 steps (larger datasets will benefit from longer training)
# - We'll reduce the target metrics to account for the small dataset size and limited training.
#
# On the topic of target metrics, there are *not* specific guidelines about what these metrics should be in practice, and you will need to conduct testing in your target deployment environment to establish good thresholds. However, from very limited testing the default values in the config file (accuracy >= 0.7, recall >= 0.5, false-positive rate <= 0.2 per hour) seem to produce models with reasonable performance.

# %%
# Load default YAML config file for training
config = yaml.load(open("openwakeword/examples/custom_model.yml", 'r').read(), yaml.Loader)
config

# %%
# Modify values in the config and save a new version

config["target_phrase"] = ["hey sebastian"]
config["model_name"] = config["target_phrase"][0].replace(" ", "_")
config["n_samples"] = 1000
config["n_samples_val"] = 1000
config["steps"] = 10000
config["target_accuracy"] = 0.6
config["target_recall"] = 0.25

config["background_paths"] = ['./audioset_16k', './fma']  # multiple background datasets are supported
config["false_positive_validation_data_path"] = "validation_set_features.npy"
config["feature_data_files"] = {"ACAV100M_sample": "openwakeword_features_ACAV100M_2000_hrs_16bit.npy"}

with open('my_model.yaml', 'w') as file:
    documents = yaml.dump(config, file)

# %% [markdown]
# # Train the Model

# %% [markdown]
# With the data downloaded and training configuration set, we can now start training the model. We'll do this in parts to better illustrate the sequence, but you can also execute every step at once for a fully automated process.

# %%
# Step 1: Generate synthetic clips
# For the number of clips we are using, this should take ~10 minutes on a free Google Colab instance with a T4 GPU
# If generation fails, you can simply run this command again as it will continue generating until the
# number of files meets the targets specified in the config file

# !{sys.executable} openwakeword/openwakeword/train.py --training_config my_model.yaml --generate_clips

# %%
# Step 2: Augment the generated clips

# !{sys.executable} openwakeword/openwakeword/train.py --training_config my_model.yaml --augment_clips

# %%
# Step 3: Train model

# !{sys.executable} openwakeword/openwakeword/train.py --training_config my_model.yaml --train_model

# %%
# Step 4 (Optional): On Google Colab, sometimes the .tflite model isn't saved correctly
# If so, run this cell to retry

# Manually save to tflite as this doesn't work right in colab
def convert_onnx_to_tflite(onnx_model_path, output_path):
    """Converts an ONNX version of an openwakeword model to the Tensorflow tflite format."""
    # imports
    import onnx
    import logging
    import tempfile
    from onnx_tf.backend import prepare
    import tensorflow as tf

    # Convert to tflite from onnx model
    onnx_model = onnx.load(onnx_model_path)
    tf_rep = prepare(onnx_model, device="CPU")
    with tempfile.TemporaryDirectory() as tmp_dir:
        tf_rep.export_graph(os.path.join(tmp_dir, "tf_model"))
        converter = tf.lite.TFLiteConverter.from_saved_model(os.path.join(tmp_dir, "tf_model"))
        tflite_model = converter.convert()

        logging.info(f"####\nSaving tflite mode to '{output_path}'")
        with open(output_path, 'wb') as f:
            f.write(tflite_model)

    return None

convert_onnx_to_tflite(f"my_custom_model/{config['model_name']}.onnx", f"my_custom_model/{config['model_name']}.tflite")

# %% [markdown]
# After the model finishes training, the auto training script will automatically convert it to ONNX and tflite versions, saving them as `my_custom_model/<model_name>.onnx/tflite` in the present working directory, where `<model_name>` is defined in the YAML training config file. Either version can be used as normal with `openwakeword`. I recommend testing them with the [`detect_from_microphone.py`](https://github.com/dscripka/openWakeWord/blob/main/examples/detect_from_microphone.py) example script to see how the model performs!

# %%
# Imports
import os
import numpy as np
import torch
import sys
from pathlib import Path
import uuid
import yaml
import datasets
import scipy
from tqdm import tqdm
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/asyncio/base_events.py", line 596, in run_forever
#     self._run_once()
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/asyncio/base_events.py", line 1890, in _run_once
#     handle._run()
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 519, in dispatch_queue
#     await self.process_one()
#   File "/Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 508, in process_one
#     await dispatch(*args)
#   File "/Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 400, in dispatch_shell
#     await result
#   File "/Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 368, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "/Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 455, in do_execute
#     res = shell.run_cell(
#   File "/Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages/ipykernel/zmqshell.py", line 577, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3048, in run_cell
#     result = self._run_cell(
#   File "/Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3103, in _run_cell
#     result = runner(coro)
#   File "/Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3308, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3490, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3550, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/rf/w8hmc77j7g711fhyb5t40t680000gn/T/ipykernel_69330/3374820726.py", line 9, in <module>
#     import datasets
#   File "/Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages/datasets/__init__.py", line 17, in <module>
#     from .arrow_dataset import Dataset
#   File "/Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages/datasets/arrow_dataset.py", line 60, in <module>
#     import pyarrow as pa
#   File "/Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages/pyarrow/__init__.py", line 61, in <module>
#     import pyarrow.lib as _lib
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[34], line 9
#       7 import uuid
#       8 import yaml
# ----> 9 import datasets
#      10 import scipy
#      11 from tqdm import tqdm
#
# File ~/crackle_ws/crackle/.venv/lib/python3.9/site-packages/datasets/__init__.py:17
#       1 # Copyright 2020 The HuggingFace Datasets Authors and the TensorFlow Datasets Authors.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 __version__ = "2.20.0"
# ---> 17 from .arrow_dataset import Dataset
#      18 from .arrow_reader import ReadInstruction
#      19 from .builder import ArrowBasedBuilder, BeamBasedBuilder, BuilderConfig, DatasetBuilder, GeneratorBasedBuilder
#
# File ~/crackle_ws/crackle/.venv/lib/python3.9/site-packages/datasets/arrow_dataset.py:60
#      58 import numpy as np
#      59 import pandas as pd
# ---> 60 import pyarrow as pa
#      61 import pyarrow.compute as pc
#      62 from fsspec.core import url_to_fs
#
# File ~/crackle_ws/crackle/.venv/lib/python3.9/site-packages/pyarrow/__init__.py:61
#      58     except ImportError:
#      59         __version__ = None
# ---> 61 import pyarrow.lib as _lib
#      62 from pyarrow.lib import (BuildInfo, RuntimeInfo, set_timezone_db_path,
#      63                          MonthDayNano, VersionInfo, cpp_build_info,
#      64                          cpp_version, cpp_version_info, runtime_info,
#      65                          cpu_count, set_cpu_count, enable_signal_handlers,
#      66                          io_thread_count, set_io_thread_count)
#      69 def show_versions():
#
# File ~/crackle_ws/crackle/.venv/lib/python3.9/site-packages/pyarrow/lib.pyx:36, in init pyarrow.lib()
#
# ImportError: numpy.core.multiarray failed to import

# %%
# Install requirements (it's recommended that you do this in a new virtual environment)

# !pip install openwakeword
# !pip install speechbrain
# !pip install datasets
# !pip install scipy matplotlib
# Out:
# Requirement already satisfied: openwakeword in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (0.6.0)
# Requirement already satisfied: onnxruntime<2,>=1.10.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from openwakeword) (1.23.2)
# Requirement already satisfied: tqdm<5.0,>=4.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from openwakeword) (4.67.1)
# Requirement already satisfied: scipy<2,>=1.3 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from openwakeword) (1.13.1)
# Requirement already satisfied: scikit-learn<2,>=1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from openwakeword) (1.7.2)
# Requirement already satisfied: requests<3,>=2.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from openwakeword) (2.32.5)
# Requirement already satisfied: coloredlogs in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from onnxruntime<2,>=1.10.0->openwakeword) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from onnxruntime<2,>=1.10.0->openwakeword) (25.9.23)
# Requirement already satisfied: numpy>=1.21.6 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from onnxruntime<2,>=1.10.0->openwakeword) (2.0.2)
# Requirement already satisfied: packaging in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from onnxruntime<2,>=1.10.0->openwakeword) (25.0)
# Requirement already satisfied: protobuf in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from onnxruntime<2,>=1.10.0->openwakeword) (6.33.0)
# Requirement already satisfied: sympy in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from onnxruntime<2,>=1.10.0->openwakeword) (1.14.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from requests<3,>=2.0->openwakeword) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from requests<3,>=2.0->openwakeword) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from requests<3,>=2.0->openwakeword) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from requests<3,>=2.0->openwakeword) (2025.10.5)
# Requirement already satisfied: joblib>=1.2.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from scikit-learn<2,>=1->openwakeword) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from scikit-learn<2,>=1->openwakeword) (3.6.0)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from coloredlogs->onnxruntime<2,>=1.10.0->openwakeword) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from sympy->onnxruntime<2,>=1.10.0->openwakeword) (1.3.0)
# Requirement already satisfied: speechbrain in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (0.5.14)
# Requirement already satisfied: hyperpyyaml in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from speechbrain) (1.2.2)
# Requirement already satisfied: joblib in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from speechbrain) (1.5.2)
# Requirement already satisfied: numpy in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from speechbrain) (2.0.2)
# Requirement already satisfied: packaging in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from speechbrain) (25.0)
# Requirement already satisfied: scipy in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from speechbrain) (1.13.1)
# Requirement already satisfied: sentencepiece in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from speechbrain) (0.2.1)
# Requirement already satisfied: torch>=1.9 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from speechbrain) (2.9.0)
# Requirement already satisfied: torchaudio in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from speechbrain) (2.9.0)
# Requirement already satisfied: tqdm in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from speechbrain) (4.67.1)
# Requirement already satisfied: huggingface-hub in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from speechbrain) (0.36.0)
# Requirement already satisfied: filelock in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from torch>=1.9->speechbrain) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from torch>=1.9->speechbrain) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from torch>=1.9->speechbrain) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from torch>=1.9->speechbrain) (3.5)
# Requirement already satisfied: jinja2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from torch>=1.9->speechbrain) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from torch>=1.9->speechbrain) (2024.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=1.9->speechbrain) (1.3.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from huggingface-hub->speechbrain) (6.0.3)
# Requirement already satisfied: requests in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from huggingface-hub->speechbrain) (2.32.5)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from huggingface-hub->speechbrain) (1.1.10)
# Requirement already satisfied: ruamel.yaml>=0.17.28 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from hyperpyyaml->speechbrain) (0.18.16)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from ruamel.yaml>=0.17.28->hyperpyyaml->speechbrain) (0.2.14)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from jinja2->torch>=1.9->speechbrain) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from requests->huggingface-hub->speechbrain) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from requests->huggingface-hub->speechbrain) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from requests->huggingface-hub->speechbrain) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from requests->huggingface-hub->speechbrain) (2025.10.5)
# Requirement already satisfied: datasets in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (4.3.0)
# Requirement already satisfied: filelock in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from datasets) (3.20.0)
# Requirement already satisfied: numpy>=1.17 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=21.0.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from datasets) (21.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from datasets) (2.3.3)
# Requirement already satisfied: requests>=2.32.2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from datasets) (2.32.5)
# Requirement already satisfied: httpx<1.0.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from datasets) (0.28.1)
# Requirement already satisfied: tqdm>=4.66.3 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.9.0,>=2023.1.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (2024.5.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from datasets) (0.36.0)
# Requirement already satisfied: packaging in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (3.13.1)
# Requirement already satisfied: anyio in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (4.11.0)
# Requirement already satisfied: certifi in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.1.10)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (1.26.18)
# Requirement already satisfied: sniffio>=1.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from anyio->httpx<1.0.0->datasets) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: scipy in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (1.13.1)
# Requirement already satisfied: matplotlib in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (3.10.7)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from scipy) (2.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %% [markdown]
# # Download Data

# %% [markdown]
# When training new openWakeWord models using the automated procedure, four specific types of data are required:
#
# 1) Synthetic examples of the target word/phrase generated with text-to-speech models
#
# 2) Synthetic examples of adversarial words/phrases generated with text-to-speech models
#
# 3) Room impulse reponses and noise/background audio data to augment the synthetic examples and make them more realistic
#
# 4) Generic "negative" audio data that is very unlikely to contain examples of the target word/phrase in the context where the model should detect it. This data can be the original audio data, or precomputed openWakeWord features ready for model training.
#
# 5) Validation data to use for early-stopping when training the model.
#
# For the purposes of this notebook, all five of these sources will either be generated manually or can be obtained from HuggingFace thanks to their excellent `datasets` library and extremely generous hosting policy. Also note that while only a portion of some datasets are downloaded, for the best possible performance it is recommended to download the entire dataset and keep a local copy for future training runs.

# %%
# Download room impulse responses collected by MIT
# https://mcdermottlab.mit.edu/Reverb/IR_Survey.html

output_dir = "./mit_rirs"
if not os.path.exists(output_dir):
    os.mkdir(output_dir)
rir_dataset = datasets.load_dataset("davidscripka/MIT_environmental_impulse_responses", split="train", streaming=True)

# Save clips to 16-bit PCM wav files
for row in tqdm(rir_dataset):
    name = row['audio']['path'].split('/')[-1]
    scipy.io.wavfile.write(os.path.join(output_dir, name), 16000, (row['audio']['array']*32767).astype(np.int16))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 7
#       5 if not os.path.exists(output_dir):
#       6     os.mkdir(output_dir)
# ----> 7 rir_dataset = datasets.load_dataset("davidscripka/MIT_environmental_impulse_responses", split="train", streaming=True)
#       9 # Save clips to 16-bit PCM wav files
#      10 for row in tqdm(rir_dataset):
#
# NameError: name 'datasets' is not defined

# %%
## Download noise and background audio

# Audioset Dataset (https://research.google.com/audioset/dataset/index.html)
# Download one part of the audioset .tar files, extract, and convert to 16khz
# For full-scale training, it's recommended to download the entire dataset from
# https://huggingface.co/datasets/agkphysics/AudioSet, and
# even potentially combine it with other background noise datasets (e.g., FSD50k, Freesound, etc.)

if not os.path.exists("audioset"):
    os.mkdir("audioset")

fname = "bal_train09.tar"
out_dir = f"audioset/{fname}"
link = "https://huggingface.co/datasets/agkphysics/AudioSet/resolve/main/data/" + fname
# !wget -O {out_dir} {link}
# !cd audioset && tar -xvf bal_train09.tar

output_dir = "./audioset_16k"
if not os.path.exists(output_dir):
    os.mkdir(output_dir)

# Convert audioset files to 16khz sample rate
audioset_dataset = datasets.Dataset.from_dict({"audio": [str(i) for i in Path("audioset/audio").glob("**/*.flac")]})
audioset_dataset = audioset_dataset.cast_column("audio", datasets.Audio(sampling_rate=16000))
for row in tqdm(audioset_dataset):
    name = row['audio']['path'].split('/')[-1].replace(".flac", ".wav")
    scipy.io.wavfile.write(os.path.join(output_dir, name), 16000, (row['audio']['array']*32767).astype(np.int16))

# Free Music Archive dataset (https://github.com/mdeff/fma)
output_dir = "./fma"
if not os.path.exists(output_dir):
    os.mkdir(output_dir)
fma_dataset = datasets.load_dataset("rudraml/fma", name="small", split="train", streaming=True)
fma_dataset = iter(fma_dataset.cast_column("audio", datasets.Audio(sampling_rate=16000)))

n_hours = 1  # use only 1 hour of clips for this example notebook, recommend increasing for full-scale training
for i in tqdm(range(n_hours*3600//30)):  # this works because the FMA dataset is all 30 second clips
    row = next(fma_dataset)
    name = row['audio']['path'].split('/')[-1].replace(".mp3", ".wav")
    scipy.io.wavfile.write(os.path.join(output_dir, name), 16000, (row['audio']['array']*32767).astype(np.int16))
    i += 1
    if i == n_hours*3600//30:
        break

# %%
# Download pre-computed openWakeWord features for training and validation

# training set (~2,000 hours from the ACAV100M Dataset)
# See https://huggingface.co/datasets/davidscripka/openwakeword_features for more information
# !wget https://huggingface.co/datasets/davidscripka/openwakeword_features/resolve/main/openwakeword_features_ACAV100M_2000_hrs_16bit.npy

# validation set for false positive rate estimation (~11 hours)
# !wget https://huggingface.co/datasets/davidscripka/openwakeword_features/resolve/main/validation_set_features.npy

# %% [markdown]
# # Define Training Configuration

# %% [markdown]
# For automated model training openWakeWord uses a specially designed training script and a [YAML](https://yaml.org/) configuration file that defines all of the information required for training a new wake word/phrase detection model.
#
# It is strongly recommended that you review [the example config file](../examples/custom_model.yml), as each value is fully documented there. For the purposes of this notebook, we'll read in the YAML file to modify certain configuration parameters before saving a new YAML file for training our example model. Specifically:
#
# - We'll train a detection model for the phrase "hey sebastian"
# - We'll only generate 5,000 positive and negative examples (to save on time for this example)
# - We'll only generate 1,000 validation positive and negative examples for early stopping (again to save time)
# - The model will only be trained for 10,000 steps (larger datasets will benefit from longer training)
# - We'll reduce the target metrics to account for the small dataset size and limited training.
#
# On the topic of target metrics, there are *not* specific guidelines about what these metrics should be in practice, and you will need to conduct testing in your target deployment environment to establish good thresholds. However, from very limited testing the default values in the config file (accuracy >= 0.7, recall >= 0.5, false-positive rate <= 0.2 per hour) seem to produce models with reasonable performance.

# %%
# Load default YAML config file for training
config = yaml.load(open("openwakeword/examples/custom_model.yml", 'r').read(), yaml.Loader)
config

# %%
# Modify values in the config and save a new version

config["target_phrase"] = ["hey sebastian"]
config["model_name"] = config["target_phrase"][0].replace(" ", "_")
config["n_samples"] = 1000
config["n_samples_val"] = 1000
config["steps"] = 10000
config["target_accuracy"] = 0.6
config["target_recall"] = 0.25

config["background_paths"] = ['./audioset_16k', './fma']  # multiple background datasets are supported
config["false_positive_validation_data_path"] = "validation_set_features.npy"
config["feature_data_files"] = {"ACAV100M_sample": "openwakeword_features_ACAV100M_2000_hrs_16bit.npy"}

with open('my_model.yaml', 'w') as file:
    documents = yaml.dump(config, file)

# %% [markdown]
# # Train the Model

# %% [markdown]
# With the data downloaded and training configuration set, we can now start training the model. We'll do this in parts to better illustrate the sequence, but you can also execute every step at once for a fully automated process.

# %%
# Step 1: Generate synthetic clips
# For the number of clips we are using, this should take ~10 minutes on a free Google Colab instance with a T4 GPU
# If generation fails, you can simply run this command again as it will continue generating until the
# number of files meets the targets specified in the config file

# !{sys.executable} openwakeword/openwakeword/train.py --training_config my_model.yaml --generate_clips

# %%
# Step 2: Augment the generated clips

# !{sys.executable} openwakeword/openwakeword/train.py --training_config my_model.yaml --augment_clips

# %%
# Step 3: Train model

# !{sys.executable} openwakeword/openwakeword/train.py --training_config my_model.yaml --train_model

# %%
# Step 4 (Optional): On Google Colab, sometimes the .tflite model isn't saved correctly
# If so, run this cell to retry

# Manually save to tflite as this doesn't work right in colab
def convert_onnx_to_tflite(onnx_model_path, output_path):
    """Converts an ONNX version of an openwakeword model to the Tensorflow tflite format."""
    # imports
    import onnx
    import logging
    import tempfile
    from onnx_tf.backend import prepare
    import tensorflow as tf

    # Convert to tflite from onnx model
    onnx_model = onnx.load(onnx_model_path)
    tf_rep = prepare(onnx_model, device="CPU")
    with tempfile.TemporaryDirectory() as tmp_dir:
        tf_rep.export_graph(os.path.join(tmp_dir, "tf_model"))
        converter = tf.lite.TFLiteConverter.from_saved_model(os.path.join(tmp_dir, "tf_model"))
        tflite_model = converter.convert()

        logging.info(f"####\nSaving tflite mode to '{output_path}'")
        with open(output_path, 'wb') as f:
            f.write(tflite_model)

    return None

convert_onnx_to_tflite(f"my_custom_model/{config['model_name']}.onnx", f"my_custom_model/{config['model_name']}.tflite")

# %% [markdown]
# After the model finishes training, the auto training script will automatically convert it to ONNX and tflite versions, saving them as `my_custom_model/<model_name>.onnx/tflite` in the present working directory, where `<model_name>` is defined in the YAML training config file. Either version can be used as normal with `openwakeword`. I recommend testing them with the [`detect_from_microphone.py`](https://github.com/dscripka/openWakeWord/blob/main/examples/detect_from_microphone.py) example script to see how the model performs!
