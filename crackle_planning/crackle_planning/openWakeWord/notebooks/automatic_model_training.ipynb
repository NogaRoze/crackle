# %% [markdown]
# # Introduction

# %% [markdown]
# This notebook demonstrates how to train custom openWakeWord models using pre-defined datasets and an automated process for dataset generation and training. While not guaranteed to always produce the best performing model, the methods shown in this notebook often produce baseline models with releatively strong performance.
#
# Manual data preparation and model training (e.g., see the [training models](training_models.ipynb) notebook) remains an option for when full control over the model development process is needed.
#
# At a high level, the automatic training process takes advantages of several techniques to try and produce a good model, including:
#
# - Early-stopping and checkpoint averaging (similar to [stochastic weight averaging](https://arxiv.org/abs/1803.05407)) to search for the best models found during training, according to the validation data
# - Variable learning rates with cosine decay and multiple cycles
# - Adaptive batch construction to focus on only high-loss examples when the model begins to converge, combined with gradient accumulation to ensure that batch sizes are still large enough for stable training
# - Cycical weight schedules for negative examples to help the model reduce false-positive rates
#
# See the contents of the `train.py` file for more details.

# %% [markdown]
# # Environment Setup

# %% [markdown]
# To begin, we'll need to install the requirements for training custom models. In particular, a relatively recent version of Pytorch and custom fork of the [piper-sample-generator](https://github.com/dscripka/piper-sample-generator) library for generating synthetic examples for the custom model.
#
# **Important Note!** Currently, automated model training is only supported on linux systems due to the requirements of the text to speech library used for synthetic sample generation (Piper). It may be possible to use Piper on Windows/Mac systems, but that has not (yet) been tested.

# %%
## Environment setup

# install piper-sample-generator (currently only supports linux systems)
# !git clone https://github.com/rhasspy/piper-sample-generator
# !wget -O piper-sample-generator/models/en_US-libritts_r-medium.pt 'https://github.com/rhasspy/piper-sample-generator/releases/download/v2.0.0/en_US-libritts_r-medium.pt'
# !pip install piper-phonemize-cross
# !pip install webrtcvad

# install openwakeword (full installation to support training)
# !git clone https://github.com/dscripka/openwakeword
# !pip install -e ./openwakeword
# !cd openwakeword

# install other dependencies
# !pip install mutagen==1.47.0
# !pip install torchinfo==1.8.0
# !pip install torchmetrics==1.2.0
# !pip install speechbrain==0.5.14
# !pip install audiomentations==0.33.0
# !pip install torch-audiomentations==0.11.0
# !pip install acoustics==0.2.6
# !pip install tensorflow-cpu==2.8.1
# !pip install tensorflow_probability==0.16.0
# !pip install onnx_tf==1.10.0
# !pip install pronouncing==0.2.0
# !pip install datasets==2.14.6
# !pip install deep-phonemizer==0.0.19

# Download required models (workaround for Colab)
import os  
os.makedirs("./openwakeword/openwakeword/resources/models", exist_ok=True)
# !wget https://github.com/dscripka/openWakeWord/releases/download/v0.5.1/embedding_model.onnx -O ./openwakeword/openwakeword/resources/models/embedding_model.onnx
# !wget https://github.com/dscripka/openWakeWord/releases/download/v0.5.1/embedding_model.tflite -O ./openwakeword/openwakeword/resources/models/embedding_model.tflite
# !wget https://github.com/dscripka/openWakeWord/releases/download/v0.5.1/melspectrogram.onnx -O ./openwakeword/openwakeword/resources/models/melspectrogram.onnx
# !wget https://github.com/dscripka/openWakeWord/releases/download/v0.5.1/melspectrogram.tflite -O ./openwakeword/openwakeword/resources/models/melspectrogram.tflite
# Out:
# fatal: destination path 'piper-sample-generator' already exists and is not an empty directory.
# --2025-10-16 19:54:01--  https://github.com/rhasspy/piper-sample-generator/releases/download/v2.0.0/en_US-libritts_r-medium.pt
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/642029941/73f4af3c-7cf8-4547-a7b9-3bd29e7f3c33?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-10-17T01%3A37%3A20Z&rscd=attachment%3B+filename%3Den_US-libritts_r-medium.pt&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-10-17T00%3A36%3A29Z&ske=2025-10-17T01%3A37%3A20Z&sks=b&skv=2018-11-09&sig=t73QFUuoCfnAdqbtnhaU15m86fk8UgBOHCmV2%2BXQXRk%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2MDY2NjA0MSwibmJmIjoxNzYwNjYyNDQxLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.5TyvdFyYkwl6qLcSbDHUTujai8QmeCNOHz9rDktGjpA&response-content-disposition=attachment%3B%20filename%3Den_US-libritts_r-medium.pt&response-content-type=application%2Foctet-stream [following]
# --2025-10-16 19:54:01--  https://release-assets.githubusercontent.com/github-production-release-asset/642029941/73f4af3c-7cf8-4547-a7b9-3bd29e7f3c33?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-10-17T01%3A37%3A20Z&rscd=attachment%3B+filename%3Den_US-libritts_r-medium.pt&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-10-17T00%3A36%3A29Z&ske=2025-10-17T01%3A37%3A20Z&sks=b&skv=2018-11-09&sig=t73QFUuoCfnAdqbtnhaU15m86fk8UgBOHCmV2%2BXQXRk%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2MDY2NjA0MSwibmJmIjoxNzYwNjYyNDQxLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.5TyvdFyYkwl6qLcSbDHUTujai8QmeCNOHz9rDktGjpA&response-content-disposition=attachment%3B%20filename%3Den_US-libritts_r-medium.pt&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 204089915 (195M) [application/octet-stream]
# Saving to: ‘piper-sample-generator/models/en_US-libritts_r-medium.pt’
#
# piper-sample-genera 100%[===================>] 194.63M  43.4MB/s    in 4.4s
#
# 2025-10-16 19:54:06 (44.0 MB/s) - ‘piper-sample-generator/models/en_US-libritts_r-medium.pt’ saved [204089915/204089915]
#
# Requirement already satisfied: piper-phonemize-cross in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (1.2.1)
# Requirement already satisfied: webrtcvad in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (2.0.10)
# fatal: destination path 'openwakeword' already exists and is not an empty directory.
# Obtaining file:///Users/nogarosenberg/crackle_ws/crackle/crackle_planning/crackle_planning/openWakeWord/notebooks/openwakeword
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: onnxruntime<2,>=1.10.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from openwakeword==0.6.0) (1.19.2)
# Requirement already satisfied: tqdm<5.0,>=4.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from openwakeword==0.6.0) (4.67.1)
# Requirement already satisfied: scipy<2,>=1.3 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from openwakeword==0.6.0) (1.13.1)
# Requirement already satisfied: scikit-learn<2,>=1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from openwakeword==0.6.0) (1.6.1)
# Requirement already satisfied: requests<3,>=2.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from openwakeword==0.6.0) (2.32.5)
# Requirement already satisfied: coloredlogs in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from onnxruntime<2,>=1.10.0->openwakeword==0.6.0) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from onnxruntime<2,>=1.10.0->openwakeword==0.6.0) (25.9.23)
# Requirement already satisfied: numpy>=1.21.6 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from onnxruntime<2,>=1.10.0->openwakeword==0.6.0) (2.0.2)
# Requirement already satisfied: packaging in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from onnxruntime<2,>=1.10.0->openwakeword==0.6.0) (25.0)
# Requirement already satisfied: protobuf in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from onnxruntime<2,>=1.10.0->openwakeword==0.6.0) (6.33.0)
# Requirement already satisfied: sympy in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from onnxruntime<2,>=1.10.0->openwakeword==0.6.0) (1.14.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from requests<3,>=2.0->openwakeword==0.6.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from requests<3,>=2.0->openwakeword==0.6.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from requests<3,>=2.0->openwakeword==0.6.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from requests<3,>=2.0->openwakeword==0.6.0) (2025.10.5)
# Requirement already satisfied: joblib>=1.2.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from scikit-learn<2,>=1->openwakeword==0.6.0) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from scikit-learn<2,>=1->openwakeword==0.6.0) (3.6.0)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from coloredlogs->onnxruntime<2,>=1.10.0->openwakeword==0.6.0) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from sympy->onnxruntime<2,>=1.10.0->openwakeword==0.6.0) (1.3.0)
# Building wheels for collected packages: openwakeword
#   Building editable for openwakeword (pyproject.toml) ... done
#   Created wheel for openwakeword: filename=openwakeword-0.6.0-0.editable-py3-none-any.whl size=17493 sha256=e40d1f77961d4b35e68a9f3357f114d569dbaab21cbc48901fbbe54b5c4c7fb5
#   Stored in directory: /private/var/folders/rf/w8hmc77j7g711fhyb5t40t680000gn/T/pip-ephem-wheel-cache-fp19bc0t/wheels/65/d6/0f/bec2a3b14a53f502a3957f9d7c336c252be0215d6b5fbd5912
# Successfully built openwakeword
# Installing collected packages: openwakeword
#   Attempting uninstall: openwakeword
#     Found existing installation: openwakeword 0.6.0
#     Uninstalling openwakeword-0.6.0:
#       Successfully uninstalled openwakeword-0.6.0
# Successfully installed openwakeword-0.6.0
# Requirement already satisfied: mutagen==1.47.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (1.47.0)
# Requirement already satisfied: torchinfo==1.8.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (1.8.0)
# Requirement already satisfied: torchmetrics==1.2.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (1.2.0)
# Requirement already satisfied: numpy>1.20.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from torchmetrics==1.2.0) (2.0.2)
# Requirement already satisfied: torch>=1.8.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from torchmetrics==1.2.0) (2.4.1)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from torchmetrics==1.2.0) (0.15.2)
# Requirement already satisfied: packaging>=17.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from lightning-utilities>=0.8.0->torchmetrics==1.2.0) (25.0)
# Requirement already satisfied: setuptools in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from lightning-utilities>=0.8.0->torchmetrics==1.2.0) (80.9.0)
# Requirement already satisfied: typing_extensions in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from lightning-utilities>=0.8.0->torchmetrics==1.2.0) (4.15.0)
# Requirement already satisfied: filelock in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from torch>=1.8.1->torchmetrics==1.2.0) (3.19.1)
# Requirement already satisfied: sympy in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from torch>=1.8.1->torchmetrics==1.2.0) (1.14.0)
# Requirement already satisfied: networkx in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from torch>=1.8.1->torchmetrics==1.2.0) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from torch>=1.8.1->torchmetrics==1.2.0) (3.1.6)
# Requirement already satisfied: fsspec in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from torch>=1.8.1->torchmetrics==1.2.0) (2023.10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from jinja2->torch>=1.8.1->torchmetrics==1.2.0) (3.0.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from sympy->torch>=1.8.1->torchmetrics==1.2.0) (1.3.0)
# Requirement already satisfied: speechbrain==0.5.14 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (0.5.14)
# Requirement already satisfied: hyperpyyaml in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from speechbrain==0.5.14) (1.2.2)
# Requirement already satisfied: joblib in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from speechbrain==0.5.14) (1.5.2)
# Requirement already satisfied: numpy in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from speechbrain==0.5.14) (2.0.2)
# Requirement already satisfied: packaging in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from speechbrain==0.5.14) (25.0)
# Requirement already satisfied: scipy in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from speechbrain==0.5.14) (1.13.1)
# Requirement already satisfied: sentencepiece in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from speechbrain==0.5.14) (0.2.1)
# Requirement already satisfied: torch>=1.9 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from speechbrain==0.5.14) (2.4.1)
# Requirement already satisfied: torchaudio in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from speechbrain==0.5.14) (2.4.1)
# Requirement already satisfied: tqdm in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from speechbrain==0.5.14) (4.67.1)
# Requirement already satisfied: huggingface-hub in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from speechbrain==0.5.14) (0.35.3)
# Requirement already satisfied: filelock in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from torch>=1.9->speechbrain==0.5.14) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from torch>=1.9->speechbrain==0.5.14) (4.15.0)
# Requirement already satisfied: sympy in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from torch>=1.9->speechbrain==0.5.14) (1.14.0)
# Requirement already satisfied: networkx in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from torch>=1.9->speechbrain==0.5.14) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from torch>=1.9->speechbrain==0.5.14) (3.1.6)
# Requirement already satisfied: fsspec in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from torch>=1.9->speechbrain==0.5.14) (2023.10.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from huggingface-hub->speechbrain==0.5.14) (6.0.3)
# Requirement already satisfied: requests in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from huggingface-hub->speechbrain==0.5.14) (2.32.5)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from huggingface-hub->speechbrain==0.5.14) (1.1.10)
# Requirement already satisfied: ruamel.yaml>=0.17.28 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from hyperpyyaml->speechbrain==0.5.14) (0.18.15)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from ruamel.yaml>=0.17.28->hyperpyyaml->speechbrain==0.5.14) (0.2.14)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from jinja2->torch>=1.9->speechbrain==0.5.14) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from requests->huggingface-hub->speechbrain==0.5.14) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from requests->huggingface-hub->speechbrain==0.5.14) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from requests->huggingface-hub->speechbrain==0.5.14) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from requests->huggingface-hub->speechbrain==0.5.14) (2025.10.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from sympy->torch>=1.9->speechbrain==0.5.14) (1.3.0)
# Requirement already satisfied: audiomentations==0.33.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (0.33.0)
# Requirement already satisfied: numpy>=1.18.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from audiomentations==0.33.0) (2.0.2)
# Requirement already satisfied: librosa!=0.10.0,<0.11.0,>=0.8.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from audiomentations==0.33.0) (0.10.2.post1)
# Requirement already satisfied: scipy<2,>=1.4.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from audiomentations==0.33.0) (1.13.1)
# Requirement already satisfied: soxr<1.0.0,>=0.3.2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from audiomentations==0.33.0) (0.5.0.post1)
# Requirement already satisfied: audioread>=2.1.9 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (3.0.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (1.6.1)
# Requirement already satisfied: joblib>=0.14 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (1.5.2)
# Requirement already satisfied: decorator>=4.3.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (5.2.1)
# Requirement already satisfied: numba>=0.51.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (0.60.0)
# Requirement already satisfied: soundfile>=0.12.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (1.8.2)
# Requirement already satisfied: typing-extensions>=4.1.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (4.15.0)
# Requirement already satisfied: lazy-loader>=0.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (1.1.2)
# Requirement already satisfied: packaging in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from lazy-loader>=0.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (25.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from numba>=0.51.0->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from pooch>=1.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (4.4.0)
# Requirement already satisfied: requests>=2.19.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from pooch>=1.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (2025.10.5)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from scikit-learn>=0.20.0->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from soundfile>=0.12.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (2.0.0)
# Requirement already satisfied: pycparser in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (2.23)
# Requirement already satisfied: torch-audiomentations==0.11.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (0.11.0)
# Requirement already satisfied: julius<0.3,>=0.2.3 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from torch-audiomentations==0.11.0) (0.2.7)
# Requirement already satisfied: librosa>=0.6.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from torch-audiomentations==0.11.0) (0.10.2.post1)
# Requirement already satisfied: torch>=1.7.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from torch-audiomentations==0.11.0) (2.4.1)
# Requirement already satisfied: torchaudio>=0.7.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from torch-audiomentations==0.11.0) (2.4.1)
# Requirement already satisfied: torch-pitch-shift>=1.2.2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from torch-audiomentations==0.11.0) (1.2.5)
# Requirement already satisfied: audioread>=2.1.9 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (2.0.2)
# Requirement already satisfied: scipy>=1.2.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (1.6.1)
# Requirement already satisfied: joblib>=0.14 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (1.5.2)
# Requirement already satisfied: decorator>=4.3.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (5.2.1)
# Requirement already satisfied: numba>=0.51.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (0.60.0)
# Requirement already satisfied: soundfile>=0.12.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (0.5.0.post1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (4.15.0)
# Requirement already satisfied: lazy-loader>=0.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (1.1.2)
# Requirement already satisfied: packaging in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from lazy-loader>=0.1->librosa>=0.6.0->torch-audiomentations==0.11.0) (25.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from numba>=0.51.0->librosa>=0.6.0->torch-audiomentations==0.11.0) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from pooch>=1.1->librosa>=0.6.0->torch-audiomentations==0.11.0) (4.4.0)
# Requirement already satisfied: requests>=2.19.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from pooch>=1.1->librosa>=0.6.0->torch-audiomentations==0.11.0) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.1->librosa>=0.6.0->torch-audiomentations==0.11.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.1->librosa>=0.6.0->torch-audiomentations==0.11.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.1->librosa>=0.6.0->torch-audiomentations==0.11.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.1->librosa>=0.6.0->torch-audiomentations==0.11.0) (2025.10.5)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from scikit-learn>=0.20.0->librosa>=0.6.0->torch-audiomentations==0.11.0) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from soundfile>=0.12.1->librosa>=0.6.0->torch-audiomentations==0.11.0) (2.0.0)
# Requirement already satisfied: pycparser in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa>=0.6.0->torch-audiomentations==0.11.0) (2.23)
# Requirement already satisfied: filelock in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from torch>=1.7.0->torch-audiomentations==0.11.0) (3.19.1)
# Requirement already satisfied: sympy in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from torch>=1.7.0->torch-audiomentations==0.11.0) (1.14.0)
# Requirement already satisfied: networkx in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from torch>=1.7.0->torch-audiomentations==0.11.0) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from torch>=1.7.0->torch-audiomentations==0.11.0) (3.1.6)
# Requirement already satisfied: fsspec in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from torch>=1.7.0->torch-audiomentations==0.11.0) (2023.10.0)
# Requirement already satisfied: primePy>=1.3 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from torch-pitch-shift>=1.2.2->torch-audiomentations==0.11.0) (1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from jinja2->torch>=1.7.0->torch-audiomentations==0.11.0) (3.0.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from sympy->torch>=1.7.0->torch-audiomentations==0.11.0) (1.3.0)
# Requirement already satisfied: acoustics==0.2.6 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (0.2.6)
# Requirement already satisfied: numpy>=1.8 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from acoustics==0.2.6) (2.0.2)
# Requirement already satisfied: scipy>=0.16 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from acoustics==0.2.6) (1.13.1)
# Requirement already satisfied: matplotlib in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from acoustics==0.2.6) (3.9.4)
# Requirement already satisfied: six>=1.4.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from acoustics==0.2.6) (1.17.0)
# Requirement already satisfied: pandas>=0.15 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from acoustics==0.2.6) (2.3.3)
# Requirement already satisfied: tabulate in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from acoustics==0.2.6) (0.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from pandas>=0.15->acoustics==0.2.6) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from pandas>=0.15->acoustics==0.2.6) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from pandas>=0.15->acoustics==0.2.6) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from matplotlib->acoustics==0.2.6) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from matplotlib->acoustics==0.2.6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from matplotlib->acoustics==0.2.6) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from matplotlib->acoustics==0.2.6) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from matplotlib->acoustics==0.2.6) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from matplotlib->acoustics==0.2.6) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from matplotlib->acoustics==0.2.6) (3.2.5)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from matplotlib->acoustics==0.2.6) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->acoustics==0.2.6) (3.23.0)
# ERROR: Could not find a version that satisfies the requirement tensorflow-cpu==2.8.1 (from versions: none)
# ERROR: No matching distribution found for tensorflow-cpu==2.8.1
# Requirement already satisfied: tensorflow_probability==0.16.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (0.16.0)
# Requirement already satisfied: absl-py in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from tensorflow_probability==0.16.0) (2.3.1)
# Requirement already satisfied: six>=1.10.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from tensorflow_probability==0.16.0) (1.17.0)
# Requirement already satisfied: numpy>=1.13.3 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from tensorflow_probability==0.16.0) (2.0.2)
# Requirement already satisfied: decorator in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from tensorflow_probability==0.16.0) (5.2.1)
# Requirement already satisfied: cloudpickle>=1.3 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from tensorflow_probability==0.16.0) (3.1.1)
# Requirement already satisfied: gast>=0.3.2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from tensorflow_probability==0.16.0) (0.6.0)
# Requirement already satisfied: dm-tree in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from tensorflow_probability==0.16.0) (0.1.8)
# Requirement already satisfied: onnx_tf==1.10.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (1.10.0)
# Requirement already satisfied: onnx>=1.10.2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from onnx_tf==1.10.0) (1.19.1)
# Requirement already satisfied: PyYAML in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from onnx_tf==1.10.0) (6.0.3)
# Requirement already satisfied: tensorflow-addons in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from onnx_tf==1.10.0) (0.23.0)
# Requirement already satisfied: numpy>=1.22 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from onnx>=1.10.2->onnx_tf==1.10.0) (2.0.2)
# Requirement already satisfied: protobuf>=4.25.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from onnx>=1.10.2->onnx_tf==1.10.0) (6.33.0)
# Requirement already satisfied: typing_extensions>=4.7.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from onnx>=1.10.2->onnx_tf==1.10.0) (4.15.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from onnx>=1.10.2->onnx_tf==1.10.0) (0.5.3)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from tensorflow-addons->onnx_tf==1.10.0) (2.13.3)
# Requirement already satisfied: packaging in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from tensorflow-addons->onnx_tf==1.10.0) (25.0)
# Requirement already satisfied: pronouncing==0.2.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (0.2.0)
# Requirement already satisfied: cmudict>=0.4.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from pronouncing==0.2.0) (1.1.1)
# Requirement already satisfied: importlib-metadata>=5 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from cmudict>=0.4.0->pronouncing==0.2.0) (8.7.0)
# Requirement already satisfied: importlib-resources>=5 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from cmudict>=0.4.0->pronouncing==0.2.0) (6.5.2)
# Requirement already satisfied: zipp>=3.20 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from importlib-metadata>=5->cmudict>=0.4.0->pronouncing==0.2.0) (3.23.0)
# Requirement already satisfied: datasets==2.14.6 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (2.14.6)
# Requirement already satisfied: numpy>=1.17 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from datasets==2.14.6) (2.0.2)
# Requirement already satisfied: pyarrow>=8.0.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from datasets==2.14.6) (21.0.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from datasets==2.14.6) (0.3.7)
# Requirement already satisfied: pandas in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from datasets==2.14.6) (2.3.3)
# Requirement already satisfied: requests>=2.19.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from datasets==2.14.6) (2.32.5)
# Requirement already satisfied: tqdm>=4.62.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from datasets==2.14.6) (4.67.1)
# Requirement already satisfied: xxhash in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from datasets==2.14.6) (3.6.0)
# Requirement already satisfied: multiprocess in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from datasets==2.14.6) (0.70.15)
# Requirement already satisfied: fsspec<=2023.10.0,>=2023.1.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from fsspec[http]<=2023.10.0,>=2023.1.0->datasets==2.14.6) (2023.10.0)
# Requirement already satisfied: aiohttp in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from datasets==2.14.6) (3.13.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from datasets==2.14.6) (0.35.3)
# Requirement already satisfied: packaging in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from datasets==2.14.6) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from datasets==2.14.6) (6.0.3)
# Requirement already satisfied: filelock in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets==2.14.6) (3.19.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets==2.14.6) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets==2.14.6) (1.1.10)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from aiohttp->datasets==2.14.6) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from aiohttp->datasets==2.14.6) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from aiohttp->datasets==2.14.6) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from aiohttp->datasets==2.14.6) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from aiohttp->datasets==2.14.6) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from aiohttp->datasets==2.14.6) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from aiohttp->datasets==2.14.6) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from aiohttp->datasets==2.14.6) (1.22.0)
# Requirement already satisfied: idna>=2.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from yarl<2.0,>=1.17.0->aiohttp->datasets==2.14.6) (3.11)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from requests>=2.19.0->datasets==2.14.6) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from requests>=2.19.0->datasets==2.14.6) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from requests>=2.19.0->datasets==2.14.6) (2025.10.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from pandas->datasets==2.14.6) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from pandas->datasets==2.14.6) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from pandas->datasets==2.14.6) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->datasets==2.14.6) (1.17.0)
# Requirement already satisfied: deep-phonemizer==0.0.19 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (0.0.19)
# Requirement already satisfied: torch>=1.2.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from deep-phonemizer==0.0.19) (2.4.1)
# Requirement already satisfied: tqdm>=4.38.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from deep-phonemizer==0.0.19) (4.67.1)
# Requirement already satisfied: PyYAML>=5.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from deep-phonemizer==0.0.19) (6.0.3)
# Requirement already satisfied: tensorboard in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from deep-phonemizer==0.0.19) (2.20.0)
# Requirement already satisfied: certifi>=2022.12.7 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from deep-phonemizer==0.0.19) (2025.10.5)
# Requirement already satisfied: wheel>=0.38.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from deep-phonemizer==0.0.19) (0.45.1)
# Requirement already satisfied: setuptools>=65.5.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from deep-phonemizer==0.0.19) (80.9.0)
# Requirement already satisfied: filelock in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from torch>=1.2.0->deep-phonemizer==0.0.19) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from torch>=1.2.0->deep-phonemizer==0.0.19) (4.15.0)
# Requirement already satisfied: sympy in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from torch>=1.2.0->deep-phonemizer==0.0.19) (1.14.0)
# Requirement already satisfied: networkx in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from torch>=1.2.0->deep-phonemizer==0.0.19) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from torch>=1.2.0->deep-phonemizer==0.0.19) (3.1.6)
# Requirement already satisfied: fsspec in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from torch>=1.2.0->deep-phonemizer==0.0.19) (2023.10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from jinja2->torch>=1.2.0->deep-phonemizer==0.0.19) (3.0.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from sympy->torch>=1.2.0->deep-phonemizer==0.0.19) (1.3.0)
# Requirement already satisfied: absl-py>=0.4 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from tensorboard->deep-phonemizer==0.0.19) (2.3.1)
# Requirement already satisfied: grpcio>=1.48.2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from tensorboard->deep-phonemizer==0.0.19) (1.75.1)
# Requirement already satisfied: markdown>=2.6.8 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from tensorboard->deep-phonemizer==0.0.19) (3.9)
# Requirement already satisfied: numpy>=1.12.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from tensorboard->deep-phonemizer==0.0.19) (2.0.2)
# Requirement already satisfied: packaging in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from tensorboard->deep-phonemizer==0.0.19) (25.0)
# Requirement already satisfied: pillow in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from tensorboard->deep-phonemizer==0.0.19) (11.3.0)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from tensorboard->deep-phonemizer==0.0.19) (6.33.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from tensorboard->deep-phonemizer==0.0.19) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from tensorboard->deep-phonemizer==0.0.19) (3.1.3)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard->deep-phonemizer==0.0.19) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard->deep-phonemizer==0.0.19) (3.23.0)
# --2025-10-16 19:54:21--  https://github.com/dscripka/openWakeWord/releases/download/v0.5.1/embedding_model.onnx
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/497407399/0233db07-b8db-4fc3-b026-b75d77fd7ae6?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-10-17T01%3A37%3A37Z&rscd=attachment%3B+filename%3Dembedding_model.onnx&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-10-17T00%3A36%3A42Z&ske=2025-10-17T01%3A37%3A37Z&sks=b&skv=2018-11-09&sig=POPGIoqB7fOJX4m3Bik%2BvhgM1UdoTbBSlTJDzYHFjXs%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2MDY2Mjc2MiwibmJmIjoxNzYwNjYyNDYyLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.H9D4PO7lHU5oOSI9k12jy2A6M658sq8BuOaWhceebBM&response-content-disposition=attachment%3B%20filename%3Dembedding_model.onnx&response-content-type=application%2Foctet-stream [following]
# --2025-10-16 19:54:22--  https://release-assets.githubusercontent.com/github-production-release-asset/497407399/0233db07-b8db-4fc3-b026-b75d77fd7ae6?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-10-17T01%3A37%3A37Z&rscd=attachment%3B+filename%3Dembedding_model.onnx&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-10-17T00%3A36%3A42Z&ske=2025-10-17T01%3A37%3A37Z&sks=b&skv=2018-11-09&sig=POPGIoqB7fOJX4m3Bik%2BvhgM1UdoTbBSlTJDzYHFjXs%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2MDY2Mjc2MiwibmJmIjoxNzYwNjYyNDYyLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.H9D4PO7lHU5oOSI9k12jy2A6M658sq8BuOaWhceebBM&response-content-disposition=attachment%3B%20filename%3Dembedding_model.onnx&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1326578 (1.3M) [application/octet-stream]
# Saving to: ‘./openwakeword/openwakeword/resources/models/embedding_model.onnx’
#
# ./openwakeword/open 100%[===================>]   1.26M  --.-KB/s    in 0.07s
#
# 2025-10-16 19:54:22 (18.4 MB/s) - ‘./openwakeword/openwakeword/resources/models/embedding_model.onnx’ saved [1326578/1326578]
#
# --2025-10-16 19:54:22--  https://github.com/dscripka/openWakeWord/releases/download/v0.5.1/embedding_model.tflite
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/497407399/4bfa8f05-dd30-45f6-b47c-c55548bb5ffc?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-10-17T01%3A37%3A03Z&rscd=attachment%3B+filename%3Dembedding_model.tflite&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-10-17T00%3A37%3A03Z&ske=2025-10-17T01%3A37%3A03Z&sks=b&skv=2018-11-09&sig=5ml0W%2FTaIvzVKUwZu3nJynHIXrU9CCSH2fxtgsUTbBs%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2MDY2Mjc2MiwibmJmIjoxNzYwNjYyNDYyLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.H9D4PO7lHU5oOSI9k12jy2A6M658sq8BuOaWhceebBM&response-content-disposition=attachment%3B%20filename%3Dembedding_model.tflite&response-content-type=application%2Foctet-stream [following]
# --2025-10-16 19:54:22--  https://release-assets.githubusercontent.com/github-production-release-asset/497407399/4bfa8f05-dd30-45f6-b47c-c55548bb5ffc?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-10-17T01%3A37%3A03Z&rscd=attachment%3B+filename%3Dembedding_model.tflite&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-10-17T00%3A37%3A03Z&ske=2025-10-17T01%3A37%3A03Z&sks=b&skv=2018-11-09&sig=5ml0W%2FTaIvzVKUwZu3nJynHIXrU9CCSH2fxtgsUTbBs%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2MDY2Mjc2MiwibmJmIjoxNzYwNjYyNDYyLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.H9D4PO7lHU5oOSI9k12jy2A6M658sq8BuOaWhceebBM&response-content-disposition=attachment%3B%20filename%3Dembedding_model.tflite&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1330312 (1.3M) [application/octet-stream]
# Saving to: ‘./openwakeword/openwakeword/resources/models/embedding_model.tflite’
#
# ./openwakeword/open 100%[===================>]   1.27M  --.-KB/s    in 0.06s
#
# 2025-10-16 19:54:22 (20.4 MB/s) - ‘./openwakeword/openwakeword/resources/models/embedding_model.tflite’ saved [1330312/1330312]
#
# --2025-10-16 19:54:23--  https://github.com/dscripka/openWakeWord/releases/download/v0.5.1/melspectrogram.onnx
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/497407399/6b613c12-b693-4220-82d5-01be396893d9?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-10-17T01%3A39%3A35Z&rscd=attachment%3B+filename%3Dmelspectrogram.onnx&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-10-17T00%3A38%3A50Z&ske=2025-10-17T01%3A39%3A35Z&sks=b&skv=2018-11-09&sig=ffzq6Wj6v1fblFu7HsUW0wx%2BURljIfWXekvuyhvPZ%2Fs%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2MDY2Mjc2MywibmJmIjoxNzYwNjYyNDYzLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.p3hunLRZgzOzj1X4Yi7EKYO36DlIOULZlj6VTBY0DpA&response-content-disposition=attachment%3B%20filename%3Dmelspectrogram.onnx&response-content-type=application%2Foctet-stream [following]
# --2025-10-16 19:54:23--  https://release-assets.githubusercontent.com/github-production-release-asset/497407399/6b613c12-b693-4220-82d5-01be396893d9?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-10-17T01%3A39%3A35Z&rscd=attachment%3B+filename%3Dmelspectrogram.onnx&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-10-17T00%3A38%3A50Z&ske=2025-10-17T01%3A39%3A35Z&sks=b&skv=2018-11-09&sig=ffzq6Wj6v1fblFu7HsUW0wx%2BURljIfWXekvuyhvPZ%2Fs%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2MDY2Mjc2MywibmJmIjoxNzYwNjYyNDYzLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.p3hunLRZgzOzj1X4Yi7EKYO36DlIOULZlj6VTBY0DpA&response-content-disposition=attachment%3B%20filename%3Dmelspectrogram.onnx&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1087958 (1.0M) [application/octet-stream]
# Saving to: ‘./openwakeword/openwakeword/resources/models/melspectrogram.onnx’
#
# ./openwakeword/open 100%[===================>]   1.04M  --.-KB/s    in 0.05s
#
# 2025-10-16 19:54:23 (19.3 MB/s) - ‘./openwakeword/openwakeword/resources/models/melspectrogram.onnx’ saved [1087958/1087958]
#
# --2025-10-16 19:54:23--  https://github.com/dscripka/openWakeWord/releases/download/v0.5.1/melspectrogram.tflite
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/497407399/14a5e610-f7fa-4157-ae44-fdaabf875683?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-10-17T01%3A45%3A26Z&rscd=attachment%3B+filename%3Dmelspectrogram.tflite&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-10-17T00%3A45%3A10Z&ske=2025-10-17T01%3A45%3A26Z&sks=b&skv=2018-11-09&sig=Uk29t7kORdQ6web9sHEWx6wpO1l7Fmah4Va1xkJsxuQ%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2MDY2Mjc2NCwibmJmIjoxNzYwNjYyNDY0LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.JlWrHvevFJpf0XiYV6neUZGL0CSWsPfx0fA4fwPnA7c&response-content-disposition=attachment%3B%20filename%3Dmelspectrogram.tflite&response-content-type=application%2Foctet-stream [following]
# --2025-10-16 19:54:24--  https://release-assets.githubusercontent.com/github-production-release-asset/497407399/14a5e610-f7fa-4157-ae44-fdaabf875683?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-10-17T01%3A45%3A26Z&rscd=attachment%3B+filename%3Dmelspectrogram.tflite&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-10-17T00%3A45%3A10Z&ske=2025-10-17T01%3A45%3A26Z&sks=b&skv=2018-11-09&sig=Uk29t7kORdQ6web9sHEWx6wpO1l7Fmah4Va1xkJsxuQ%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2MDY2Mjc2NCwibmJmIjoxNzYwNjYyNDY0LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.JlWrHvevFJpf0XiYV6neUZGL0CSWsPfx0fA4fwPnA7c&response-content-disposition=attachment%3B%20filename%3Dmelspectrogram.tflite&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1092516 (1.0M) [application/octet-stream]
# Saving to: ‘./openwakeword/openwakeword/resources/models/melspectrogram.tflite’
#
# ./openwakeword/open 100%[===================>]   1.04M  --.-KB/s    in 0.07s
#
# 2025-10-16 19:54:24 (15.5 MB/s) - ‘./openwakeword/openwakeword/resources/models/melspectrogram.tflite’ saved [1092516/1092516]

# %%
# Imports

import os
import numpy as np
import torch
import sys
from pathlib import Path
import uuid
import yaml
import datasets
import scipy
from tqdm import tqdm
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 10
#       8 import uuid
#       9 import yaml
# ---> 10 import datasets
#      11 import scipy
#      12 from tqdm import tqdm
#
# File ~/crackle_ws/crackle/.venv/lib/python3.9/site-packages/datasets/__init__.py:18
#       1 # ruff: noqa
#       2 # Copyright 2020 The HuggingFace Datasets Authors and the TensorFlow Datasets Authors.
#       3 #
#    (...)
#      13 # See the License for the specific language governing permissions and
#      14 # limitations under the License.
#      16 __version__ = "2.19.0"
# ---> 18 from .arrow_dataset import Dataset
#      19 from .arrow_reader import ReadInstruction
#      20 from .builder import ArrowBasedBuilder, BeamBasedBuilder, BuilderConfig, DatasetBuilder, GeneratorBasedBuilder
#
# File ~/crackle_ws/crackle/.venv/lib/python3.9/site-packages/datasets/arrow_dataset.py:77
#      75 from . import config
#      76 from .arrow_reader import ArrowReader
# ---> 77 from .arrow_writer import ArrowWriter, OptimizedTypedSequence
#      78 from .data_files import sanitize_patterns
#      79 from .download.streaming_download_manager import xgetsize
#
# File ~/crackle_ws/crackle/.venv/lib/python3.9/site-packages/datasets/arrow_writer.py:46
#      44 from .table import array_cast, cast_array_to_feature, embed_table_storage, table_cast
#      45 from .utils import logging
# ---> 46 from .utils import tqdm as hf_tqdm
#      47 from .utils.file_utils import hash_url_to_filename
#      48 from .utils.py_utils import asdict, first_non_null_value
#
# File ~/crackle_ws/crackle/.venv/lib/python3.9/site-packages/datasets/utils/tqdm.py:47
#      43 import warnings
#      45 from tqdm.auto import tqdm as old_tqdm
# ---> 47 from ..config import HF_DATASETS_DISABLE_PROGRESS_BARS
#      50 # `HF_DATASETS_DISABLE_PROGRESS_BARS` is `Optional[bool]` while `_hf_datasets_progress_bars_disabled`
#      51 # is a `bool`. If `HF_DATASETS_DISABLE_PROGRESS_BARS` is set to True or False, it has priority.
#      52 # If `HF_DATASETS_DISABLE_PROGRESS_BARS` is None, it means the user have not set the
#    (...)
#      55 #
#      56 # By default, progress bars are enabled.
#      57 _hf_datasets_progress_bars_disabled: bool = HF_DATASETS_DISABLE_PROGRESS_BARS or False
#
# ImportError: cannot import name 'HF_DATASETS_DISABLE_PROGRESS_BARS' from 'datasets.config' (/Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages/datasets/config.py)

# %%
# Install requirements (it's recommended that you do this in a new virtual environment)

# !pip install openwakeword
# !pip install speechbrain
# !pip install datasets
# !pip install scipy matplotlib
# Out:
# Requirement already satisfied: openwakeword in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (0.6.0)
# Requirement already satisfied: onnxruntime<2,>=1.10.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from openwakeword) (1.19.2)
# Requirement already satisfied: tqdm<5.0,>=4.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from openwakeword) (4.67.1)
# Requirement already satisfied: scipy<2,>=1.3 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from openwakeword) (1.13.1)
# Requirement already satisfied: scikit-learn<2,>=1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from openwakeword) (1.6.1)
# Requirement already satisfied: requests<3,>=2.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from openwakeword) (2.32.5)
# Requirement already satisfied: coloredlogs in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from onnxruntime<2,>=1.10.0->openwakeword) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from onnxruntime<2,>=1.10.0->openwakeword) (25.9.23)
# Requirement already satisfied: numpy>=1.21.6 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from onnxruntime<2,>=1.10.0->openwakeword) (2.0.2)
# Requirement already satisfied: packaging in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from onnxruntime<2,>=1.10.0->openwakeword) (25.0)
# Requirement already satisfied: protobuf in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from onnxruntime<2,>=1.10.0->openwakeword) (6.33.0)
# Requirement already satisfied: sympy in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from onnxruntime<2,>=1.10.0->openwakeword) (1.14.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from requests<3,>=2.0->openwakeword) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from requests<3,>=2.0->openwakeword) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from requests<3,>=2.0->openwakeword) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from requests<3,>=2.0->openwakeword) (2025.10.5)
# Requirement already satisfied: joblib>=1.2.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from scikit-learn<2,>=1->openwakeword) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from scikit-learn<2,>=1->openwakeword) (3.6.0)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from coloredlogs->onnxruntime<2,>=1.10.0->openwakeword) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from sympy->onnxruntime<2,>=1.10.0->openwakeword) (1.3.0)
# Requirement already satisfied: speechbrain in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (1.0.3)
# Requirement already satisfied: hyperpyyaml in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from speechbrain) (1.2.2)
# Requirement already satisfied: joblib in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from speechbrain) (1.5.2)
# Requirement already satisfied: numpy in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from speechbrain) (2.0.2)
# Requirement already satisfied: packaging in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from speechbrain) (25.0)
# Requirement already satisfied: scipy in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from speechbrain) (1.13.1)
# Requirement already satisfied: sentencepiece in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from speechbrain) (0.2.1)
# Requirement already satisfied: torch>=1.9 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from speechbrain) (2.4.1)
# Requirement already satisfied: torchaudio in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from speechbrain) (2.4.1)
# Requirement already satisfied: tqdm in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from speechbrain) (4.67.1)
# Requirement already satisfied: huggingface_hub in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from speechbrain) (0.35.3)
# Requirement already satisfied: filelock in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from torch>=1.9->speechbrain) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from torch>=1.9->speechbrain) (4.15.0)
# Requirement already satisfied: sympy in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from torch>=1.9->speechbrain) (1.14.0)
# Requirement already satisfied: networkx in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from torch>=1.9->speechbrain) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from torch>=1.9->speechbrain) (3.1.6)
# Requirement already satisfied: fsspec in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from torch>=1.9->speechbrain) (2025.9.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from huggingface_hub->speechbrain) (6.0.3)
# Requirement already satisfied: requests in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from huggingface_hub->speechbrain) (2.32.5)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from huggingface_hub->speechbrain) (1.1.10)
# Requirement already satisfied: ruamel.yaml>=0.17.28 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from hyperpyyaml->speechbrain) (0.18.15)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from ruamel.yaml>=0.17.28->hyperpyyaml->speechbrain) (0.2.14)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from jinja2->torch>=1.9->speechbrain) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from requests->huggingface_hub->speechbrain) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from requests->huggingface_hub->speechbrain) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from requests->huggingface_hub->speechbrain) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from requests->huggingface_hub->speechbrain) (2025.10.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from sympy->torch>=1.9->speechbrain) (1.3.0)
# Requirement already satisfied: datasets in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (4.2.0)
# Requirement already satisfied: filelock in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from datasets) (3.19.1)
# Requirement already satisfied: numpy>=1.17 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=21.0.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from datasets) (21.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from datasets) (0.4.0)
# Requirement already satisfied: pandas in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from datasets) (2.3.3)
# Requirement already satisfied: requests>=2.32.2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from datasets) (2.32.5)
# Requirement already satisfied: httpx<1.0.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from datasets) (0.28.1)
# Requirement already satisfied: tqdm>=4.66.3 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.9.0,>=2023.1.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (2025.9.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from datasets) (0.35.3)
# Requirement already satisfied: packaging in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (3.13.0)
# Requirement already satisfied: anyio in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from httpx<1.0.0->datasets) (4.11.0)
# Requirement already satisfied: certifi in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from httpx<1.0.0->datasets) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.1.10)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from anyio->httpx<1.0.0->datasets) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from anyio->httpx<1.0.0->datasets) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: scipy in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (1.13.1)
# Requirement already satisfied: matplotlib in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (3.9.4)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from scipy) (2.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.23.0)
# Requirement already satisfied: six>=1.5 in /Users/nogarosenberg/crackle_ws/crackle/.venv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %% [markdown]
# # Download Data

# %% [markdown]
# When training new openWakeWord models using the automated procedure, four specific types of data are required:
#
# 1) Synthetic examples of the target word/phrase generated with text-to-speech models
#
# 2) Synthetic examples of adversarial words/phrases generated with text-to-speech models
#
# 3) Room impulse reponses and noise/background audio data to augment the synthetic examples and make them more realistic
#
# 4) Generic "negative" audio data that is very unlikely to contain examples of the target word/phrase in the context where the model should detect it. This data can be the original audio data, or precomputed openWakeWord features ready for model training.
#
# 5) Validation data to use for early-stopping when training the model.
#
# For the purposes of this notebook, all five of these sources will either be generated manually or can be obtained from HuggingFace thanks to their excellent `datasets` library and extremely generous hosting policy. Also note that while only a portion of some datasets are downloaded, for the best possible performance it is recommended to download the entire dataset and keep a local copy for future training runs.

# %%
# Download room impulse responses collected by MIT
# https://mcdermottlab.mit.edu/Reverb/IR_Survey.html

output_dir = "./mit_rirs"
if not os.path.exists(output_dir):
    os.mkdir(output_dir)
rir_dataset = datasets.load_dataset("davidscripka/MIT_environmental_impulse_responses", split="train", streaming=True)

# Save clips to 16-bit PCM wav files
for row in tqdm(rir_dataset):
    name = row['audio']['path'].split('/')[-1]
    scipy.io.wavfile.write(os.path.join(output_dir, name), 16000, (row['audio']['array']*32767).astype(np.int16))

# %%
## Download noise and background audio

# Audioset Dataset (https://research.google.com/audioset/dataset/index.html)
# Download one part of the audioset .tar files, extract, and convert to 16khz
# For full-scale training, it's recommended to download the entire dataset from
# https://huggingface.co/datasets/agkphysics/AudioSet, and
# even potentially combine it with other background noise datasets (e.g., FSD50k, Freesound, etc.)

if not os.path.exists("audioset"):
    os.mkdir("audioset")

fname = "bal_train09.tar"
out_dir = f"audioset/{fname}"
link = "https://huggingface.co/datasets/agkphysics/AudioSet/resolve/main/data/" + fname
# !wget -O {out_dir} {link}
# !cd audioset && tar -xvf bal_train09.tar

output_dir = "./audioset_16k"
if not os.path.exists(output_dir):
    os.mkdir(output_dir)

# Convert audioset files to 16khz sample rate
audioset_dataset = datasets.Dataset.from_dict({"audio": [str(i) for i in Path("audioset/audio").glob("**/*.flac")]})
audioset_dataset = audioset_dataset.cast_column("audio", datasets.Audio(sampling_rate=16000))
for row in tqdm(audioset_dataset):
    name = row['audio']['path'].split('/')[-1].replace(".flac", ".wav")
    scipy.io.wavfile.write(os.path.join(output_dir, name), 16000, (row['audio']['array']*32767).astype(np.int16))

# Free Music Archive dataset (https://github.com/mdeff/fma)
output_dir = "./fma"
if not os.path.exists(output_dir):
    os.mkdir(output_dir)
fma_dataset = datasets.load_dataset("rudraml/fma", name="small", split="train", streaming=True)
fma_dataset = iter(fma_dataset.cast_column("audio", datasets.Audio(sampling_rate=16000)))

n_hours = 1  # use only 1 hour of clips for this example notebook, recommend increasing for full-scale training
for i in tqdm(range(n_hours*3600//30)):  # this works because the FMA dataset is all 30 second clips
    row = next(fma_dataset)
    name = row['audio']['path'].split('/')[-1].replace(".mp3", ".wav")
    scipy.io.wavfile.write(os.path.join(output_dir, name), 16000, (row['audio']['array']*32767).astype(np.int16))
    i += 1
    if i == n_hours*3600//30:
        break

# %%
# Download pre-computed openWakeWord features for training and validation

# training set (~2,000 hours from the ACAV100M Dataset)
# See https://huggingface.co/datasets/davidscripka/openwakeword_features for more information
# !wget https://huggingface.co/datasets/davidscripka/openwakeword_features/resolve/main/openwakeword_features_ACAV100M_2000_hrs_16bit.npy

# validation set for false positive rate estimation (~11 hours)
# !wget https://huggingface.co/datasets/davidscripka/openwakeword_features/resolve/main/validation_set_features.npy

# %% [markdown]
# # Define Training Configuration

# %% [markdown]
# For automated model training openWakeWord uses a specially designed training script and a [YAML](https://yaml.org/) configuration file that defines all of the information required for training a new wake word/phrase detection model.
#
# It is strongly recommended that you review [the example config file](../examples/custom_model.yml), as each value is fully documented there. For the purposes of this notebook, we'll read in the YAML file to modify certain configuration parameters before saving a new YAML file for training our example model. Specifically:
#
# - We'll train a detection model for the phrase "hey sebastian"
# - We'll only generate 5,000 positive and negative examples (to save on time for this example)
# - We'll only generate 1,000 validation positive and negative examples for early stopping (again to save time)
# - The model will only be trained for 10,000 steps (larger datasets will benefit from longer training)
# - We'll reduce the target metrics to account for the small dataset size and limited training.
#
# On the topic of target metrics, there are *not* specific guidelines about what these metrics should be in practice, and you will need to conduct testing in your target deployment environment to establish good thresholds. However, from very limited testing the default values in the config file (accuracy >= 0.7, recall >= 0.5, false-positive rate <= 0.2 per hour) seem to produce models with reasonable performance.

# %%
# Load default YAML config file for training
config = yaml.load(open("openwakeword/examples/custom_model.yml", 'r').read(), yaml.Loader)
config

# %%
# Modify values in the config and save a new version

config["target_phrase"] = ["hey sebastian"]
config["model_name"] = config["target_phrase"][0].replace(" ", "_")
config["n_samples"] = 1000
config["n_samples_val"] = 1000
config["steps"] = 10000
config["target_accuracy"] = 0.6
config["target_recall"] = 0.25

config["background_paths"] = ['./audioset_16k', './fma']  # multiple background datasets are supported
config["false_positive_validation_data_path"] = "validation_set_features.npy"
config["feature_data_files"] = {"ACAV100M_sample": "openwakeword_features_ACAV100M_2000_hrs_16bit.npy"}

with open('my_model.yaml', 'w') as file:
    documents = yaml.dump(config, file)

# %% [markdown]
# # Train the Model

# %% [markdown]
# With the data downloaded and training configuration set, we can now start training the model. We'll do this in parts to better illustrate the sequence, but you can also execute every step at once for a fully automated process.

# %%
# Step 1: Generate synthetic clips
# For the number of clips we are using, this should take ~10 minutes on a free Google Colab instance with a T4 GPU
# If generation fails, you can simply run this command again as it will continue generating until the
# number of files meets the targets specified in the config file

# !{sys.executable} openwakeword/openwakeword/train.py --training_config my_model.yaml --generate_clips

# %%
# Step 2: Augment the generated clips

# !{sys.executable} openwakeword/openwakeword/train.py --training_config my_model.yaml --augment_clips

# %%
# Step 3: Train model

# !{sys.executable} openwakeword/openwakeword/train.py --training_config my_model.yaml --train_model

# %%
# Step 4 (Optional): On Google Colab, sometimes the .tflite model isn't saved correctly
# If so, run this cell to retry

# Manually save to tflite as this doesn't work right in colab
def convert_onnx_to_tflite(onnx_model_path, output_path):
    """Converts an ONNX version of an openwakeword model to the Tensorflow tflite format."""
    # imports
    import onnx
    import logging
    import tempfile
    from onnx_tf.backend import prepare
    import tensorflow as tf

    # Convert to tflite from onnx model
    onnx_model = onnx.load(onnx_model_path)
    tf_rep = prepare(onnx_model, device="CPU")
    with tempfile.TemporaryDirectory() as tmp_dir:
        tf_rep.export_graph(os.path.join(tmp_dir, "tf_model"))
        converter = tf.lite.TFLiteConverter.from_saved_model(os.path.join(tmp_dir, "tf_model"))
        tflite_model = converter.convert()

        logging.info(f"####\nSaving tflite mode to '{output_path}'")
        with open(output_path, 'wb') as f:
            f.write(tflite_model)

    return None

convert_onnx_to_tflite(f"my_custom_model/{config['model_name']}.onnx", f"my_custom_model/{config['model_name']}.tflite")

# %% [markdown]
# After the model finishes training, the auto training script will automatically convert it to ONNX and tflite versions, saving them as `my_custom_model/<model_name>.onnx/tflite` in the present working directory, where `<model_name>` is defined in the YAML training config file. Either version can be used as normal with `openwakeword`. I recommend testing them with the [`detect_from_microphone.py`](https://github.com/dscripka/openWakeWord/blob/main/examples/detect_from_microphone.py) example script to see how the model performs!
